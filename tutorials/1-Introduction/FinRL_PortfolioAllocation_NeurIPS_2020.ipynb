# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL/blob/master/tutorials/advanced/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Portfolio Allocation
#
# Tutorials to use OpenAI DRL to perform portfolio allocation in one Jupyter Notebook | Presented at NeurIPS 2020: Deep RL Workshop
#
# * This blog is based on our paper: FinRL: A Deep Reinforcement Learning Library for Automated Stock Trading in Quantitative Finance, presented at NeurIPS 2020: Deep RL Workshop.
# * Check out medium blog for detailed explanations:
# * Please report any issues to our Github: https://github.com/AI4Finance-Foundation/FinRL/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for portfolio alloacation. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A represents the weight of a stock in the porfolio: a ∈ (-1,1). Assume our stock pool includes N stocks, we can use a list [a<sub>1</sub>, a<sub>2</sub>, ... , a<sub>N</sub>] to determine the weight for each stock in the porfotlio, where a<sub>i</sub> ∈ (-1,1), a<sub>1</sub>+ a<sub>2</sub>+...+a<sub>N</sub>=1. For example, "The weight of AAPL in the portfolio is 10%." is [0.1 , ...].
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
      
# install finrl library
#%pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git
# Out:
# Num GPUs Available:  1

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')
# %matplotlib inline
import datetime

from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline,convert_daily_return_to_pyfolio_ts
from finrl.meta.data_processor import DataProcessor
import sys
sys.path.append("../FinRL-Library")
# Out:
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
dp = YahooFinanceProcessor()
df = dp.download_data(start_date = '2008-01-01',
                     end_date = '2021-10-31',
                     ticker_list = config_tickers.DOW_30_TICKER, time_interval='1D')
# Out:
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# Shape of DataFrame:  (101615, 9)

# %%
df.head()
# Out:
#          date       open       high        low      close      adjcp  \
# 0  2008-01-02   7.116786   7.152143   6.876786   6.958571   5.949703
# 1  2008-01-02  46.599998  47.040001  46.259998  46.599998  35.443794
# 2  2008-01-02  52.090000  52.320000  50.790001  51.040001  40.326855
# 3  2008-01-02  87.570000  87.839996  86.000000  86.620003  63.481628
# 4  2008-01-02  72.559998  72.669998  70.050003  70.629997  47.176800
#
#        volume   tic  day
# 0  1079178800  AAPL    2
# 1     7934400  AMGN    2
# 2     8053700   AXP    2
# 3     4303000    BA    2
# 4     6337800   CAT    2

# %%
df.shape
# Out:
# (101615, 9)

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    use_turbulence=False,
                    user_defined_feature = False)

df = fe.preprocess_data(df)
# Out:
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   indicator_df = indicator_df.append(
# Successfully added technical indicators

# %%
df.shape
# Out:
# (97524, 17)

# %%
df.head()
# Out:
#              date       open       high        low      close      adjcp  \
# 0      2008-01-02   7.116786   7.152143   6.876786   6.958571   5.949703
# 3483   2008-01-02  46.599998  47.040001  46.259998  46.599998  35.443794
# 6966   2008-01-02  52.090000  52.320000  50.790001  51.040001  40.326855
# 10449  2008-01-02  87.570000  87.839996  86.000000  86.620003  63.481628
# 13932  2008-01-02  72.559998  72.669998  70.050003  70.629997  47.176800
#
#            volume   tic  day  macd   boll_ub   boll_lb  rsi_30     cci_30  \
# 0      1079178800  AAPL    2   0.0  6.964725  6.955632   100.0 -66.666667
# 3483      7934400  AMGN    2   0.0  6.964725  6.955632   100.0 -66.666667
# 6966      8053700   AXP    2   0.0  6.964725  6.955632   100.0 -66.666667
# 10449     4303000    BA    2   0.0  6.964725  6.955632   100.0 -66.666667
# 13932     6337800   CAT    2   0.0  6.964725  6.955632   100.0 -66.666667
#
#        dx_30  close_30_sma  close_60_sma
# 0      100.0      6.958571      6.958571
# 3483   100.0     46.599998     46.599998
# 6966   100.0     51.040001     51.040001
# 10449  100.0     86.620003     86.620003
# 13932  100.0     70.629997     70.629997

# %% [markdown]
# ## Add covariance matrix as states

# %%
# add covariance matrix as states
df=df.sort_values(['date','tic'],ignore_index=True)
df.index = df.date.factorize()[0]

cov_list = []
return_list = []

# look back is one year
lookback=252
for i in range(lookback,len(df.index.unique())):
  data_lookback = df.loc[i-lookback:i,:]
  price_lookback=data_lookback.pivot_table(index = 'date',columns = 'tic', values = 'close')
  return_lookback = price_lookback.pct_change().dropna()
  return_list.append(return_lookback)

  covs = return_lookback.cov().values 
  cov_list.append(covs)

  
df_cov = pd.DataFrame({'date':df.date.unique()[lookback:],'cov_list':cov_list,'return_list':return_list})
df = df.merge(df_cov, on='date')
df = df.sort_values(['date','tic']).reset_index(drop=True)

# %%
df.shape
# Out:
# (90468, 19)

# %%
df.head()
# Out:
#          date       open       high        low      close      adjcp  \
# 0  2008-12-31   3.070357   3.133571   3.047857   3.048214   2.606278
# 1  2008-12-31  57.110001  58.220001  57.060001  57.750000  43.924454
# 2  2008-12-31  17.969999  18.750000  17.910000  18.549999  14.852881
# 3  2008-12-31  41.590000  43.049999  41.500000  42.669998  32.005886
# 4  2008-12-31  43.700001  45.099998  43.700001  44.669998  30.628826
#
#       volume   tic  day      macd    boll_ub    boll_lb     rsi_30  \
# 0  607541200  AAPL    2 -0.097446   3.649552   2.895305  42.254771
# 1    6287200  AMGN    2  0.216368  58.947401  56.388599  51.060614
# 2    9625600   AXP    2 -1.191668  23.723023  16.106977  42.521170
# 3    5443100    BA    2 -0.391219  42.894634  38.486366  47.290375
# 4    6277400   CAT    2  0.979845  45.785565  38.404435  51.073052
#
#        cci_30      dx_30  close_30_sma  close_60_sma  \
# 0  -80.847207  16.129793      3.243631      3.375887
# 1   51.895357  10.432018     56.671334     56.044333
# 2  -74.811722  25.776759     20.030000     22.412000
# 3  157.922391   5.366299     40.432000     43.304500
# 4   98.904653  26.331746     40.266000     39.918333
#
#                                             cov_list  \
# 0  [[0.001348968986171653, 0.00042841264280825875...
# 1  [[0.001348968986171653, 0.00042841264280825875...
# 2  [[0.001348968986171653, 0.00042841264280825875...
# 3  [[0.001348968986171653, 0.00042841264280825875...
# 4  [[0.001348968986171653, 0.00042841264280825875...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 1  tic             AAPL      AMGN       AXP      ...
# 2  tic             AAPL      AMGN       AXP      ...
# 3  tic             AAPL      AMGN       AXP      ...
# 4  tic             AAPL      AMGN       AXP      ...

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.

# %% [markdown]
# ## Training data split: 2009-01-01 to 2020-07-01

# %%
train = data_split(df, '2009-01-01','2020-07-01')
#trade = data_split(df, '2020-01-01', config.END_DATE)

# %%
train.head()
# Out:
#          date       open       high        low      close      adjcp  \
# 0  2009-01-02   3.067143   3.251429   3.041429   3.241071   2.771173
# 0  2009-01-02  58.590000  59.080002  57.750000  58.990002  44.867596
# 0  2009-01-02  18.570000  19.520000  18.400000  19.330000  15.477425
# 0  2009-01-02  42.799999  45.560001  42.779999  45.250000  33.941090
# 0  2009-01-02  44.910000  46.980000  44.709999  46.910000  32.164726
#
#       volume   tic  day      macd    boll_ub    boll_lb     rsi_30  \
# 0  746015200  AAPL    4 -0.082758   3.633600   2.892864  45.440193
# 0    6547900  AMGN    4  0.320448  59.148360  56.339640  52.756859
# 0   10955700   AXP    4 -1.059847  23.489423  16.086577  43.923322
# 0    7010200    BA    4 -0.019566  43.926849  37.932151  50.664690
# 0    7117200   CAT    4  1.248426  46.543072  38.372928  53.534743
#
#        cci_30      dx_30  close_30_sma  close_60_sma  \
# 0  -30.508777   2.140064      3.244631      3.376833
# 0   94.549630   0.814217     56.759667     56.166000
# 0  -42.018825  16.335101     20.028333     22.263333
# 0  275.696308  20.494464     40.621667     43.237334
# 0  131.675975  34.637448     40.623333     39.911333
#
#                                             cov_list  \
# 0  [[0.001366150662406761, 0.000433938195725591, ...
# 0  [[0.001366150662406761, 0.000433938195725591, ...
# 0  [[0.001366150662406761, 0.000433938195725591, ...
# 0  [[0.001366150662406761, 0.000433938195725591, ...
# 0  [[0.001366150662406761, 0.000433938195725591, ...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...

# %% [markdown]
# ## Environment for Portfolio Allocation

# %%
import numpy as np
import pandas as pd
from gym.utils import seeding
import gym
from gym import spaces
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv


class StockPortfolioEnv(gym.Env):
    """A single stock trading environment for OpenAI gym

    Attributes
    ----------
        df: DataFrame
            input data
        stock_dim : int
            number of unique stocks
        hmax : int
            maximum number of shares to trade
        initial_amount : int
            start money
        transaction_cost_pct: float
            transaction cost percentage per trade
        reward_scaling: float
            scaling factor for reward, good for training
        state_space: int
            the dimension of input features
        action_space: int
            equals stock dimension
        tech_indicator_list: list
            a list of technical indicator names
        turbulence_threshold: int
            a threshold to control risk aversion
        day: int
            an increment number to control date

    Methods
    -------
    _sell_stock()
        perform sell action based on the sign of the action
    _buy_stock()
        perform buy action based on the sign of the action
    step()
        at each step the agent will return actions, then 
        we will calculate the reward, and return the next observation.
    reset()
        reset the environment
    render()
        use render to return other functions
    save_asset_memory()
        return account value at each time step
    save_action_memory()
        return actions/positions at each time step
        

    """
    metadata = {'render.modes': ['human']}

    def __init__(self, 
                df,
                stock_dim,
                hmax,
                initial_amount,
                transaction_cost_pct,
                reward_scaling,
                state_space,
                action_space,
                tech_indicator_list,
                turbulence_threshold=None,
                lookback=252,
                day = 0):
        #super(StockEnv, self).__init__()
        #money = 10 , scope = 1
        self.day = day
        self.lookback=lookback
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.transaction_cost_pct =transaction_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list

        # action_space normalization and shape is self.stock_dim
        self.action_space = spaces.Box(low = 0, high = 1,shape = (self.action_space,)) 
        # Shape = (34, 30)
        # covariance matrix + technical indicators
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape = (self.state_space+len(self.tech_indicator_list),self.state_space))

        # load data from a pandas dataframe
        self.data = self.df.loc[self.day,:]
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        self.terminal = False     
        self.turbulence_threshold = turbulence_threshold        
        # initalize state: inital portfolio return + individual stock return + individual weights
        self.portfolio_value = self.initial_amount

        # memorize portfolio value each step
        self.asset_memory = [self.initial_amount]
        # memorize portfolio return each step
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]]

        
    def step(self, actions):
        # print(self.day)
        self.terminal = self.day >= len(self.df.index.unique())-1
        # print(actions)

        if self.terminal:
            df = pd.DataFrame(self.portfolio_return_memory)
            df.columns = ['daily_return']
            plt.plot(df.daily_return.cumsum(),'r')
            plt.savefig('results/cumulative_reward.png')
            plt.close()
            
            plt.plot(self.portfolio_return_memory,'r')
            plt.savefig('results/rewards.png')
            plt.close()

            print("=================================")
            print("begin_total_asset:{}".format(self.asset_memory[0]))           
            print("end_total_asset:{}".format(self.portfolio_value))

            df_daily_return = pd.DataFrame(self.portfolio_return_memory)
            df_daily_return.columns = ['daily_return']
            if df_daily_return['daily_return'].std() !=0:
              sharpe = (252**0.5)*df_daily_return['daily_return'].mean()/ \
                       df_daily_return['daily_return'].std()
              print("Sharpe: ",sharpe)
            print("=================================")
            
            return self.state, self.reward, self.terminal,{}

        else:
            #print("Model actions: ",actions)
            # actions are the portfolio weight
            # normalize to sum of 1
            #if (np.array(actions) - np.array(actions).min()).sum() != 0:
            #  norm_actions = (np.array(actions) - np.array(actions).min()) / (np.array(actions) - np.array(actions).min()).sum()
            #else:
            #  norm_actions = actions
            weights = self.softmax_normalization(actions) 
            #print("Normalized actions: ", weights)
            self.actions_memory.append(weights)
            last_day_memory = self.data

            #load next state
            self.day += 1
            self.data = self.df.loc[self.day,:]
            self.covs = self.data['cov_list'].values[0]
            self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
            #print(self.state)
            # calcualte portfolio return
            # individual stocks' return * weight
            portfolio_return = sum(((self.data.close.values / last_day_memory.close.values)-1)*weights)
            # update portfolio value
            new_portfolio_value = self.portfolio_value*(1+portfolio_return)
            self.portfolio_value = new_portfolio_value

            # save into memory
            self.portfolio_return_memory.append(portfolio_return)
            self.date_memory.append(self.data.date.unique()[0])            
            self.asset_memory.append(new_portfolio_value)

            # the reward is the new portfolio value or end portfolo value
            self.reward = new_portfolio_value 
            #print("Step reward: ", self.reward)
            #self.reward = self.reward*self.reward_scaling

        return self.state, self.reward, self.terminal, {}

    def reset(self):
        self.asset_memory = [self.initial_amount]
        self.day = 0
        self.data = self.df.loc[self.day,:]
        # load states
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        self.portfolio_value = self.initial_amount
        #self.cost = 0
        #self.trades = 0
        self.terminal = False 
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]] 
        return self.state
    
    def render(self, mode='human'):
        return self.state
        
    def softmax_normalization(self, actions):
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator/denominator
        return softmax_output

    
    def save_asset_memory(self):
        date_list = self.date_memory
        portfolio_return = self.portfolio_return_memory
        #print(len(date_list))
        #print(len(asset_list))
        df_account_value = pd.DataFrame({'date':date_list,'daily_return':portfolio_return})
        return df_account_value

    def save_action_memory(self):
        # date and close price length must match actions length
        date_list = self.date_memory
        df_date = pd.DataFrame(date_list)
        df_date.columns = ['date']
        
        action_list = self.actions_memory
        df_actions = pd.DataFrame(action_list)
        df_actions.columns = self.data.tic.values
        df_actions.index = df_date.date
        #df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %%
stock_dimension = len(train.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 28, State Space: 28

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "transaction_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": config.INDICATORS, 
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4
    
}

e_train_gym = StockPortfolioEnv(df = train, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
# initialize
agent = DRLAgent(env = env_train)

# %% [markdown]
# ### Model 1: **A2C**

# %%
agent = DRLAgent(env = env_train)

A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)
# Out:
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0002}
# Using cuda device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000)
# Out:
# -------------------------------------
# | time/                 |           |
# |    fps                | 454       |
# |    iterations         | 100       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 99        |
# |    policy_loss        | 1.8e+08   |
# |    reward             | 1523248.6 |
# |    std                | 0.997     |
# |    value_loss         | 2.44e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 463       |
# |    iterations         | 200       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 199       |
# |    policy_loss        | 2.11e+08  |
# |    reward             | 1848945.4 |
# |    std                | 0.996     |
# |    value_loss         | 3.59e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 465       |
# |    iterations         | 300       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 299       |
# |    policy_loss        | 2.96e+08  |
# |    reward             | 2693186.8 |
# |    std                | 0.996     |
# |    value_loss         | 8.08e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 468       |
# |    iterations         | 400       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 399       |
# |    policy_loss        | 3.67e+08  |
# |    reward             | 3090370.8 |
# |    std                | 0.995     |
# |    value_loss         | 9.61e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 468       |
# |    iterations         | 500       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 499       |
# |    policy_loss        | 4.66e+08  |
# |    reward             | 3929004.0 |
# |    std                | 0.995     |
# |    value_loss         | 1.72e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4414632.528424182
# Sharpe:  0.7991742948879627
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 451       |
# |    iterations         | 600       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 599       |
# |    policy_loss        | 1.28e+08  |
# |    reward             | 1100225.1 |
# |    std                | 0.995     |
# |    value_loss         | 1.2e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 449       |
# |    iterations         | 700       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 699       |
# |    policy_loss        | 2.03e+08  |
# |    reward             | 1655289.4 |
# |    std                | 0.996     |
# |    value_loss         | 3.02e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 448       |
# |    iterations         | 800       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 799       |
# |    policy_loss        | 2.67e+08  |
# |    reward             | 2296261.0 |
# |    std                | 0.995     |
# |    value_loss         | 5.67e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 448       |
# |    iterations         | 900       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 899       |
# |    policy_loss        | 3.4e+08   |
# |    reward             | 3026690.8 |
# |    std                | 0.994     |
# |    value_loss         | 9.72e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 448       |
# |    iterations         | 1000      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 999       |
# |    policy_loss        | 4.17e+08  |
# |    reward             | 3423706.0 |
# |    std                | 0.994     |
# |    value_loss         | 1.3e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 448       |
# |    iterations         | 1100      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1099      |
# |    policy_loss        | 5.08e+08  |
# |    reward             | 4326120.0 |
# |    std                | 0.993     |
# |    value_loss         | 2.1e+14   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4474483.656404156
# Sharpe:  0.806792766217785
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 445       |
# |    iterations         | 1200      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1199      |
# |    policy_loss        | 1.43e+08  |
# |    reward             | 1257796.1 |
# |    std                | 0.992     |
# |    value_loss         | 1.6e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 1300      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1299      |
# |    policy_loss        | 1.89e+08  |
# |    reward             | 1548220.1 |
# |    std                | 0.991     |
# |    value_loss         | 2.63e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 445       |
# |    iterations         | 1400      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1399      |
# |    policy_loss        | 2.62e+08  |
# |    reward             | 2312374.0 |
# |    std                | 0.99      |
# |    value_loss         | 5.53e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 444       |
# |    iterations         | 1500      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1499      |
# |    policy_loss        | 3.37e+08  |
# |    reward             | 3012280.5 |
# |    std                | 0.989     |
# |    value_loss         | 9.01e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 444       |
# |    iterations         | 1600      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1599      |
# |    policy_loss        | 4.53e+08  |
# |    reward             | 3875453.0 |
# |    std                | 0.989     |
# |    value_loss         | 1.57e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 443       |
# |    iterations         | 1700      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1699      |
# |    policy_loss        | 5.25e+08  |
# |    reward             | 4796699.5 |
# |    std                | 0.989     |
# |    value_loss         | 2.33e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4892336.996689007
# Sharpe:  0.8468427397158846
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 441       |
# |    iterations         | 1800      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1799      |
# |    policy_loss        | 1.77e+08  |
# |    reward             | 1495060.1 |
# |    std                | 0.988     |
# |    value_loss         | 2.29e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 440       |
# |    iterations         | 1900      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1899      |
# |    policy_loss        | 2.18e+08  |
# |    reward             | 1911314.2 |
# |    std                | 0.987     |
# |    value_loss         | 3.93e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 440       |
# |    iterations         | 2000      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1999      |
# |    policy_loss        | 3.15e+08  |
# |    reward             | 2609428.2 |
# |    std                | 0.987     |
# |    value_loss         | 6.99e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 440       |
# |    iterations         | 2100      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2099      |
# |    policy_loss        | 3.52e+08  |
# |    reward             | 3046224.2 |
# |    std                | 0.987     |
# |    value_loss         | 9.75e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 441       |
# |    iterations         | 2200      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2199      |
# |    policy_loss        | 5.06e+08  |
# |    reward             | 3896815.0 |
# |    std                | 0.986     |
# |    value_loss         | 1.81e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 441       |
# |    iterations         | 2300      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2299      |
# |    policy_loss        | 5.06e+08  |
# |    reward             | 3663496.2 |
# |    std                | 0.987     |
# |    value_loss         | 1.93e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4714565.697411103
# Sharpe:  0.8219773156591732
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 440       |
# |    iterations         | 2400      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2399      |
# |    policy_loss        | 1.63e+08  |
# |    reward             | 1371136.1 |
# |    std                | 0.986     |
# |    value_loss         | 1.91e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 440       |
# |    iterations         | 2500      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2499      |
# |    policy_loss        | 2.13e+08  |
# |    reward             | 1841718.8 |
# |    std                | 0.986     |
# |    value_loss         | 3.49e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 441       |
# |    iterations         | 2600      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2599      |
# |    policy_loss        | 2.91e+08  |
# |    reward             | 2553033.5 |
# |    std                | 0.986     |
# |    value_loss         | 6.86e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 442       |
# |    iterations         | 2700      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2699      |
# |    policy_loss        | 3.32e+08  |
# |    reward             | 2819418.5 |
# |    std                | 0.986     |
# |    value_loss         | 8.5e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 442       |
# |    iterations         | 2800      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2799      |
# |    policy_loss        | 4.55e+08  |
# |    reward             | 3885769.5 |
# |    std                | 0.985     |
# |    value_loss         | 1.57e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4368977.926033409
# Sharpe:  0.7912934576993055
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 441       |
# |    iterations         | 2900      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2899      |
# |    policy_loss        | 1.02e+08  |
# |    reward             | 843906.06 |
# |    std                | 0.985     |
# |    value_loss         | 8.53e+12  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 441       |
# |    iterations         | 3000      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2999      |
# |    policy_loss        | 2.02e+08  |
# |    reward             | 1639680.8 |
# |    std                | 0.984     |
# |    value_loss         | 2.84e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 442       |
# |    iterations         | 3100      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3099      |
# |    policy_loss        | 2.52e+08  |
# |    reward             | 2025495.0 |
# |    std                | 0.984     |
# |    value_loss         | 4.32e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 443       |
# |    iterations         | 3200      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3199      |
# |    policy_loss        | 3.1e+08   |
# |    reward             | 2800886.8 |
# |    std                | 0.984     |
# |    value_loss         | 8.07e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 443       |
# |    iterations         | 3300      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3299      |
# |    policy_loss        | 3.58e+08  |
# |    reward             | 3400248.0 |
# |    std                | 0.984     |
# |    value_loss         | 1.22e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 444       |
# |    iterations         | 3400      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3399      |
# |    policy_loss        | 5.01e+08  |
# |    reward             | 4271017.0 |
# |    std                | 0.984     |
# |    value_loss         | 1.92e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4636973.733625006
# Sharpe:  0.8226473555465558
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 443       |
# |    iterations         | 3500      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3499      |
# |    policy_loss        | 1.33e+08  |
# |    reward             | 1160661.9 |
# |    std                | 0.983     |
# |    value_loss         | 1.34e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 443       |
# |    iterations         | 3600      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3599      |
# |    policy_loss        | 1.91e+08  |
# |    reward             | 1636532.5 |
# |    std                | 0.983     |
# |    value_loss         | 2.78e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 444       |
# |    iterations         | 3700      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3699      |
# |    policy_loss        | 2.61e+08  |
# |    reward             | 2119275.5 |
# |    std                | 0.983     |
# |    value_loss         | 4.61e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 444       |
# |    iterations         | 3800      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3799      |
# |    policy_loss        | 2.92e+08  |
# |    reward             | 2755727.0 |
# |    std                | 0.983     |
# |    value_loss         | 7.75e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 445       |
# |    iterations         | 3900      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3899      |
# |    policy_loss        | 3.67e+08  |
# |    reward             | 3164486.5 |
# |    std                | 0.982     |
# |    value_loss         | 1.06e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 445       |
# |    iterations         | 4000      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3999      |
# |    policy_loss        | 4.99e+08  |
# |    reward             | 4344185.0 |
# |    std                | 0.982     |
# |    value_loss         | 1.95e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4217746.740474855
# Sharpe:  0.773111179496195
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 441       |
# |    iterations         | 4100      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4099      |
# |    policy_loss        | 1.62e+08  |
# |    reward             | 1370941.4 |
# |    std                | 0.982     |
# |    value_loss         | 1.93e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 442       |
# |    iterations         | 4200      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4199      |
# |    policy_loss        | 1.87e+08  |
# |    reward             | 1683060.6 |
# |    std                | 0.982     |
# |    value_loss         | 2.96e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 442       |
# |    iterations         | 4300      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4299      |
# |    policy_loss        | 2.83e+08  |
# |    reward             | 2526128.0 |
# |    std                | 0.981     |
# |    value_loss         | 6.73e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 443       |
# |    iterations         | 4400      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4399      |
# |    policy_loss        | 3.49e+08  |
# |    reward             | 3085884.8 |
# |    std                | 0.98      |
# |    value_loss         | 1.06e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 443       |
# |    iterations         | 4500      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4499      |
# |    policy_loss        | 4.51e+08  |
# |    reward             | 4247763.0 |
# |    std                | 0.98      |
# |    value_loss         | 1.89e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 443       |
# |    iterations         | 4600      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4599      |
# |    policy_loss        | 5.68e+08  |
# |    reward             | 5115397.0 |
# |    std                | 0.979     |
# |    value_loss         | 2.83e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4858401.277444041
# Sharpe:  0.8438924260964026
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 442       |
# |    iterations         | 4700      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4699      |
# |    policy_loss        | 1.53e+08  |
# |    reward             | 1449395.1 |
# |    std                | 0.978     |
# |    value_loss         | 2.12e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 442       |
# |    iterations         | 4800      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4799      |
# |    policy_loss        | 2.13e+08  |
# |    reward             | 1872885.4 |
# |    std                | 0.977     |
# |    value_loss         | 3.73e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 443       |
# |    iterations         | 4900      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4899      |
# |    policy_loss        | 3.11e+08  |
# |    reward             | 2771395.5 |
# |    std                | 0.977     |
# |    value_loss         | 8.04e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 443       |
# |    iterations         | 5000      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4999      |
# |    policy_loss        | 3.54e+08  |
# |    reward             | 3147008.2 |
# |    std                | 0.977     |
# |    value_loss         | 1.08e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 444       |
# |    iterations         | 5100      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5099      |
# |    policy_loss        | 4.92e+08  |
# |    reward             | 4351399.5 |
# |    std                | 0.976     |
# |    value_loss         | 1.93e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 444       |
# |    iterations         | 5200      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5199      |
# |    policy_loss        | 5.65e+08  |
# |    reward             | 4813482.0 |
# |    std                | 0.976     |
# |    value_loss         | 2.46e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5188824.302249646
# Sharpe:  0.8726901197054721
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 444       |
# |    iterations         | 5300      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5299      |
# |    policy_loss        | 1.77e+08  |
# |    reward             | 1557104.2 |
# |    std                | 0.975     |
# |    value_loss         | 2.53e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 445       |
# |    iterations         | 5400      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5399      |
# |    policy_loss        | 2.42e+08  |
# |    reward             | 1971165.2 |
# |    std                | 0.974     |
# |    value_loss         | 4.39e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 445       |
# |    iterations         | 5500      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5499      |
# |    policy_loss        | 3.08e+08  |
# |    reward             | 2900022.8 |
# |    std                | 0.974     |
# |    value_loss         | 8.16e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 445       |
# |    iterations         | 5600      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5599      |
# |    policy_loss        | 3.66e+08  |
# |    reward             | 3297006.8 |
# |    std                | 0.973     |
# |    value_loss         | 1.17e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 5700      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5699      |
# |    policy_loss        | 5.09e+08  |
# |    reward             | 4620838.0 |
# |    std                | 0.972     |
# |    value_loss         | 2.49e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4970882.96240493
# Sharpe:  0.8530475266263655
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 446      |
# |    iterations         | 5800     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -38.9    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 5799     |
# |    policy_loss        | 1.09e+08 |
# |    reward             | 943928.0 |
# |    std                | 0.972    |
# |    value_loss         | 9.06e+12 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 5900      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5899      |
# |    policy_loss        | 1.76e+08  |
# |    reward             | 1578368.2 |
# |    std                | 0.972     |
# |    value_loss         | 2.61e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 6000      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5999      |
# |    policy_loss        | 2.38e+08  |
# |    reward             | 1987350.4 |
# |    std                | 0.972     |
# |    value_loss         | 4.24e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 6100      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6099      |
# |    policy_loss        | 3.28e+08  |
# |    reward             | 2691072.2 |
# |    std                | 0.972     |
# |    value_loss         | 7.98e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 6200      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6199      |
# |    policy_loss        | 3.56e+08  |
# |    reward             | 3178044.8 |
# |    std                | 0.972     |
# |    value_loss         | 1.11e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 6300      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6299      |
# |    policy_loss        | 4.76e+08  |
# |    reward             | 4236321.0 |
# |    std                | 0.971     |
# |    value_loss         | 1.85e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4416001.732872789
# Sharpe:  0.7974738162432988
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 6400      |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6399      |
# |    policy_loss        | 1.34e+08  |
# |    reward             | 1257245.1 |
# |    std                | 0.971     |
# |    value_loss         | 1.55e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 6500      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6499      |
# |    policy_loss        | 1.73e+08  |
# |    reward             | 1494720.4 |
# |    std                | 0.97      |
# |    value_loss         | 2.61e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 6600      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6599      |
# |    policy_loss        | 2.41e+08  |
# |    reward             | 2231663.2 |
# |    std                | 0.97      |
# |    value_loss         | 5.16e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 6700      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6699      |
# |    policy_loss        | 3.24e+08  |
# |    reward             | 2668165.8 |
# |    std                | 0.969     |
# |    value_loss         | 7.76e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 6800      |
# |    time_elapsed       | 75        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6799      |
# |    policy_loss        | 4.17e+08  |
# |    reward             | 3582831.5 |
# |    std                | 0.969     |
# |    value_loss         | 1.38e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 6900      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6899      |
# |    policy_loss        | 5.01e+08  |
# |    reward             | 4423900.0 |
# |    std                | 0.968     |
# |    value_loss         | 2.03e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4573850.715809837
# Sharpe:  0.8142840204820977
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 7000      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6999      |
# |    policy_loss        | 1.47e+08  |
# |    reward             | 1367331.1 |
# |    std                | 0.968     |
# |    value_loss         | 1.85e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 7100      |
# |    time_elapsed       | 79        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7099      |
# |    policy_loss        | 2.13e+08  |
# |    reward             | 1824791.8 |
# |    std                | 0.968     |
# |    value_loss         | 3.44e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 7200      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7199      |
# |    policy_loss        | 2.72e+08  |
# |    reward             | 2544108.8 |
# |    std                | 0.968     |
# |    value_loss         | 6.65e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 7300      |
# |    time_elapsed       | 81        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7299      |
# |    policy_loss        | 3.29e+08  |
# |    reward             | 2898949.5 |
# |    std                | 0.967     |
# |    value_loss         | 8.73e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 7400      |
# |    time_elapsed       | 82        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7399      |
# |    policy_loss        | 5.56e+08  |
# |    reward             | 4426215.5 |
# |    std                | 0.966     |
# |    value_loss         | 2.08e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 7500      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7499      |
# |    policy_loss        | 6.37e+08  |
# |    reward             | 5129297.0 |
# |    std                | 0.966     |
# |    value_loss         | 2.91e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4869599.457158076
# Sharpe:  0.8434407688669431
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 7600      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7599      |
# |    policy_loss        | 1.71e+08  |
# |    reward             | 1402562.2 |
# |    std                | 0.965     |
# |    value_loss         | 2.02e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 7700      |
# |    time_elapsed       | 86        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7699      |
# |    policy_loss        | 2.09e+08  |
# |    reward             | 1874316.9 |
# |    std                | 0.964     |
# |    value_loss         | 3.69e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 7800      |
# |    time_elapsed       | 87        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7799      |
# |    policy_loss        | 3.14e+08  |
# |    reward             | 2848875.2 |
# |    std                | 0.963     |
# |    value_loss         | 8.65e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 7900      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7899      |
# |    policy_loss        | 3.68e+08  |
# |    reward             | 3250857.0 |
# |    std                | 0.963     |
# |    value_loss         | 1.05e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 8000      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -38.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7999      |
# |    policy_loss        | 5.1e+08   |
# |    reward             | 4398961.0 |
# |    std                | 0.962     |
# |    value_loss         | 2.1e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 8100      |
# |    time_elapsed       | 90        |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -38.6     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8099      |
# |    policy_loss        | 6.13e+08  |
# |    reward             | 4927583.5 |
# |    std                | 0.961     |
# |    value_loss         | 2.73e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4983145.432554643
# Sharpe:  0.8538892240774006
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 8200      |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -38.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8199      |
# |    policy_loss        | 1.87e+08  |
# |    reward             | 1630127.9 |
# |    std                | 0.96      |
# |    value_loss         | 2.8e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 8300      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -38.6     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8299      |
# |    policy_loss        | 2.33e+08  |
# |    reward             | 1995492.2 |
# |    std                | 0.96      |
# |    value_loss         | 4.19e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 8400      |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -38.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8399      |
# |    policy_loss        | 3.28e+08  |
# |    reward             | 2859639.2 |
# |    std                | 0.959     |
# |    value_loss         | 9.5e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 8500      |
# |    time_elapsed       | 94        |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -38.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8499      |
# |    policy_loss        | 3.8e+08   |
# |    reward             | 3311239.8 |
# |    std                | 0.959     |
# |    value_loss         | 1.13e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 8600      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -38.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8599      |
# |    policy_loss        | 4.94e+08  |
# |    reward             | 4472610.0 |
# |    std                | 0.958     |
# |    value_loss         | 2.04e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4609202.840046201
# Sharpe:  0.8175782127262136
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 8700      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -38.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8699      |
# |    policy_loss        | 1.23e+08  |
# |    reward             | 1078001.1 |
# |    std                | 0.959     |
# |    value_loss         | 1.1e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 8800      |
# |    time_elapsed       | 98        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -38.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8799      |
# |    policy_loss        | 1.97e+08  |
# |    reward             | 1636371.4 |
# |    std                | 0.958     |
# |    value_loss         | 2.89e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 8900      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -38.5     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8899      |
# |    policy_loss        | 2.46e+08  |
# |    reward             | 2245464.5 |
# |    std                | 0.958     |
# |    value_loss         | 5.38e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 9000      |
# |    time_elapsed       | 100       |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -38.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8999      |
# |    policy_loss        | 3.55e+08  |
# |    reward             | 3008813.0 |
# |    std                | 0.957     |
# |    value_loss         | 9.44e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 9100      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -38.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9099      |
# |    policy_loss        | 3.78e+08  |
# |    reward             | 3485820.8 |
# |    std                | 0.956     |
# |    value_loss         | 1.3e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 9200      |
# |    time_elapsed       | 102       |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -38.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9199      |
# |    policy_loss        | 5.77e+08  |
# |    reward             | 4493633.5 |
# |    std                | 0.955     |
# |    value_loss         | 2.24e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4605481.7599245785
# Sharpe:  0.8174053827104762
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 9300      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -38.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9299      |
# |    policy_loss        | 1.46e+08  |
# |    reward             | 1302527.1 |
# |    std                | 0.955     |
# |    value_loss         | 1.84e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 9400      |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -38.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9399      |
# |    policy_loss        | 1.9e+08   |
# |    reward             | 1681539.4 |
# |    std                | 0.955     |
# |    value_loss         | 2.72e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 9500      |
# |    time_elapsed       | 106       |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -38.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9499      |
# |    policy_loss        | 2.6e+08   |
# |    reward             | 2433971.0 |
# |    std                | 0.954     |
# |    value_loss         | 6.11e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 9600      |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -38.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9599      |
# |    policy_loss        | 3.22e+08  |
# |    reward             | 2907546.8 |
# |    std                | 0.954     |
# |    value_loss         | 8.85e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 448       |
# |    iterations         | 9700      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -38.4     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9699      |
# |    policy_loss        | 4.41e+08  |
# |    reward             | 3784346.0 |
# |    std                | 0.953     |
# |    value_loss         | 1.51e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 448       |
# |    iterations         | 9800      |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -38.4     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9799      |
# |    policy_loss        | 5.87e+08  |
# |    reward             | 4718920.5 |
# |    std                | 0.952     |
# |    value_loss         | 2.31e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4812363.566276804
# Sharpe:  0.840417751644372
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 447       |
# |    iterations         | 9900      |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -38.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9899      |
# |    policy_loss        | 1.58e+08  |
# |    reward             | 1471063.1 |
# |    std                | 0.952     |
# |    value_loss         | 2.26e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 448       |
# |    iterations         | 10000     |
# |    time_elapsed       | 111       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -38.3     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9999      |
# |    policy_loss        | 2.1e+08   |
# |    reward             | 1914638.2 |
# |    std                | 0.952     |
# |    value_loss         | 3.86e+13  |
# -------------------------------------

# %%
trained_a2c.save('trained_a2c.zip')

# %% [markdown]
# ### Model 2: **PPO**

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.005,
    "learning_rate": 0.0001,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.0001, 'batch_size': 128}
# Using cuda device

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=80000)
# Out:
# ----------------------------------
# | time/              |           |
# |    fps             | 653       |
# |    iterations      | 1         |
# |    time_elapsed    | 3         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 3248046.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4276221.2118751295
# Sharpe:  0.7834859829760609
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 593            |
# |    iterations           | 2              |
# |    time_elapsed         | 6              |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | -1.1787051e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 6.73e+14       |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -3.9e-07       |
# |    reward               | 2314801.5      |
# |    std                  | 1              |
# |    value_loss           | 1.24e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4670587.081607881
# Sharpe:  0.8246935721576395
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 570            |
# |    iterations           | 3              |
# |    time_elapsed         | 10             |
# |    total_timesteps      | 6144           |
# | train/                  |                |
# |    approx_kl            | -1.2136297e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 5.96e-08       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.08e+15       |
# |    n_updates            | 20             |
# |    policy_gradient_loss | -4.9e-07       |
# |    reward               | 1309336.4      |
# |    std                  | 1              |
# |    value_loss           | 2.23e+15       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 565            |
# |    iterations           | 4              |
# |    time_elapsed         | 14             |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -1.1641532e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.46e+15       |
# |    n_updates            | 30             |
# |    policy_gradient_loss | -3.17e-07      |
# |    reward               | 4140143.5      |
# |    std                  | 1              |
# |    value_loss           | 3.05e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4615554.38917974
# Sharpe:  0.8230693911313977
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 560            |
# |    iterations           | 5              |
# |    time_elapsed         | 18             |
# |    total_timesteps      | 10240          |
# | train/                  |                |
# |    approx_kl            | -1.1903467e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 9.77e+14       |
# |    n_updates            | 40             |
# |    policy_gradient_loss | -5.55e-07      |
# |    reward               | 2958957.5      |
# |    std                  | 1              |
# |    value_loss           | 1.96e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4573160.454381619
# Sharpe:  0.8185842824364473
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 559            |
# |    iterations           | 6              |
# |    time_elapsed         | 21             |
# |    total_timesteps      | 12288          |
# | train/                  |                |
# |    approx_kl            | -1.1030352e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -2.38e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.02e+15       |
# |    n_updates            | 50             |
# |    policy_gradient_loss | -5.79e-07      |
# |    reward               | 1670697.2      |
# |    std                  | 1              |
# |    value_loss           | 2.06e+15       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 557           |
# |    iterations           | 7             |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | -1.231092e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.34e+15      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -4.13e-07     |
# |    reward               | 5112542.5     |
# |    std                  | 1             |
# |    value_loss           | 2.85e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4977399.200170279
# Sharpe:  0.8599966342395832
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 554            |
# |    iterations           | 8              |
# |    time_elapsed         | 29             |
# |    total_timesteps      | 16384          |
# | train/                  |                |
# |    approx_kl            | -1.1612428e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 1.79e-07       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.35e+15       |
# |    n_updates            | 70             |
# |    policy_gradient_loss | -4.22e-07      |
# |    reward               | 3004363.8      |
# |    std                  | 1              |
# |    value_loss           | 2.96e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4873885.934003797
# Sharpe:  0.8461151156091358
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 554            |
# |    iterations           | 9              |
# |    time_elapsed         | 33             |
# |    total_timesteps      | 18432          |
# | train/                  |                |
# |    approx_kl            | -1.1175871e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 5.96e-08       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 8.81e+14       |
# |    n_updates            | 80             |
# |    policy_gradient_loss | -5.56e-07      |
# |    reward               | 2109960.8      |
# |    std                  | 1              |
# |    value_loss           | 1.49e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4363287.3897231
# Sharpe:  0.7946369062777047
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 552            |
# |    iterations           | 10             |
# |    time_elapsed         | 37             |
# |    total_timesteps      | 20480          |
# | train/                  |                |
# |    approx_kl            | -1.2485543e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.23e+15       |
# |    n_updates            | 90             |
# |    policy_gradient_loss | -3.97e-07      |
# |    reward               | 1323182.9      |
# |    std                  | 1              |
# |    value_loss           | 2.5e+15        |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 551            |
# |    iterations           | 11             |
# |    time_elapsed         | 40             |
# |    total_timesteps      | 22528          |
# | train/                  |                |
# |    approx_kl            | -1.2369128e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.5e+15        |
# |    n_updates            | 100            |
# |    policy_gradient_loss | -4.8e-07       |
# |    reward               | 4227230.5      |
# |    std                  | 1              |
# |    value_loss           | 2.94e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4593267.98777155
# Sharpe:  0.8180185495003834
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 550            |
# |    iterations           | 12             |
# |    time_elapsed         | 44             |
# |    total_timesteps      | 24576          |
# | train/                  |                |
# |    approx_kl            | -1.1234079e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -2.38e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 8.34e+14       |
# |    n_updates            | 110            |
# |    policy_gradient_loss | -5.38e-07      |
# |    reward               | 2671705.8      |
# |    std                  | 1              |
# |    value_loss           | 1.81e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4533676.516257733
# Sharpe:  0.8133867299110616
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 550            |
# |    iterations           | 13             |
# |    time_elapsed         | 48             |
# |    total_timesteps      | 26624          |
# | train/                  |                |
# |    approx_kl            | -1.1292286e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.12e+15       |
# |    n_updates            | 120            |
# |    policy_gradient_loss | -5.05e-07      |
# |    reward               | 1671896.6      |
# |    std                  | 1              |
# |    value_loss           | 2.23e+15       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 550            |
# |    iterations           | 14             |
# |    time_elapsed         | 52             |
# |    total_timesteps      | 28672          |
# | train/                  |                |
# |    approx_kl            | -1.1874363e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.55e+15       |
# |    n_updates            | 130            |
# |    policy_gradient_loss | -3.51e-07      |
# |    reward               | 4488508.5      |
# |    std                  | 1              |
# |    value_loss           | 2.89e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4473928.663154162
# Sharpe:  0.8075318557666109
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 550            |
# |    iterations           | 15             |
# |    time_elapsed         | 55             |
# |    total_timesteps      | 30720          |
# | train/                  |                |
# |    approx_kl            | -1.2165401e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 5.96e-08       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.2e+15        |
# |    n_updates            | 140            |
# |    policy_gradient_loss | -4.62e-07      |
# |    reward               | 2725785.8      |
# |    std                  | 1              |
# |    value_loss           | 2.51e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4648629.618600926
# Sharpe:  0.8213432353755185
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 549            |
# |    iterations           | 16             |
# |    time_elapsed         | 59             |
# |    total_timesteps      | 32768          |
# | train/                  |                |
# |    approx_kl            | -1.2980308e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 7.82e+14       |
# |    n_updates            | 150            |
# |    policy_gradient_loss | -4.74e-07      |
# |    reward               | 1924989.2      |
# |    std                  | 1              |
# |    value_loss           | 1.71e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4682002.290259033
# Sharpe:  0.8227656018056219
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 547            |
# |    iterations           | 17             |
# |    time_elapsed         | 63             |
# |    total_timesteps      | 34816          |
# | train/                  |                |
# |    approx_kl            | -1.2601959e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 5.96e-08       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.33e+15       |
# |    n_updates            | 160            |
# |    policy_gradient_loss | -5.16e-07      |
# |    reward               | 1040164.8      |
# |    std                  | 1              |
# |    value_loss           | 2.6e+15        |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 547            |
# |    iterations           | 18             |
# |    time_elapsed         | 67             |
# |    total_timesteps      | 36864          |
# | train/                  |                |
# |    approx_kl            | -1.1874363e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.44e+15       |
# |    n_updates            | 170            |
# |    policy_gradient_loss | -3.41e-07      |
# |    reward               | 3529947.2      |
# |    std                  | 1              |
# |    value_loss           | 2.91e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4833145.045370513
# Sharpe:  0.8455774514058448
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 547            |
# |    iterations           | 19             |
# |    time_elapsed         | 71             |
# |    total_timesteps      | 38912          |
# | train/                  |                |
# |    approx_kl            | -1.0448275e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 7.23e+14       |
# |    n_updates            | 180            |
# |    policy_gradient_loss | -7.05e-07      |
# |    reward               | 2525645.8      |
# |    std                  | 1              |
# |    value_loss           | 1.54e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4827939.089381582
# Sharpe:  0.8441956019458345
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 547           |
# |    iterations           | 20            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | -1.231092e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.12e+15      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -5.32e-07     |
# |    reward               | 1456709.1     |
# |    std                  | 1             |
# |    value_loss           | 2.4e+15       |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 548            |
# |    iterations           | 21             |
# |    time_elapsed         | 78             |
# |    total_timesteps      | 43008          |
# | train/                  |                |
# |    approx_kl            | -1.2660166e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.53e+15       |
# |    n_updates            | 200            |
# |    policy_gradient_loss | -3.03e-07      |
# |    reward               | 3918319.8      |
# |    std                  | 1              |
# |    value_loss           | 3.12e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4401071.437964565
# Sharpe:  0.8006590713371965
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 548            |
# |    iterations           | 22             |
# |    time_elapsed         | 82             |
# |    total_timesteps      | 45056          |
# | train/                  |                |
# |    approx_kl            | -1.2165401e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.02e+15       |
# |    n_updates            | 210            |
# |    policy_gradient_loss | -4.38e-07      |
# |    reward               | 3038556.8      |
# |    std                  | 1              |
# |    value_loss           | 2.12e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5087594.012376692
# Sharpe:  0.865208253169797
# =================================
# ---------------------------------------------
# | time/                   |                 |
# |    fps                  | 549             |
# |    iterations           | 23              |
# |    time_elapsed         | 85              |
# |    total_timesteps      | 47104           |
# | train/                  |                 |
# |    approx_kl            | -1.21071935e-08 |
# |    clip_fraction        | 0               |
# |    clip_range           | 0.2             |
# |    entropy_loss         | -39.7           |
# |    explained_variance   | 1.19e-07        |
# |    learning_rate        | 0.0001          |
# |    loss                 | 8.65e+14        |
# |    n_updates            | 220             |
# |    policy_gradient_loss | -5.27e-07       |
# |    reward               | 1875785.1       |
# |    std                  | 1               |
# |    value_loss           | 1.89e+15        |
# ---------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 550            |
# |    iterations           | 24             |
# |    time_elapsed         | 89             |
# |    total_timesteps      | 49152          |
# | train/                  |                |
# |    approx_kl            | -1.2136297e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.59e+15       |
# |    n_updates            | 230            |
# |    policy_gradient_loss | -4.46e-07      |
# |    reward               | 4728448.5      |
# |    std                  | 1              |
# |    value_loss           | 3.01e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4958626.624174752
# Sharpe:  0.8548747885176976
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 551            |
# |    iterations           | 25             |
# |    time_elapsed         | 92             |
# |    total_timesteps      | 51200          |
# | train/                  |                |
# |    approx_kl            | -1.2223609e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.57e+15       |
# |    n_updates            | 240            |
# |    policy_gradient_loss | -3.8e-07       |
# |    reward               | 3402412.8      |
# |    std                  | 1              |
# |    value_loss           | 3.31e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4758209.989212274
# Sharpe:  0.8372940909317667
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 551            |
# |    iterations           | 26             |
# |    time_elapsed         | 96             |
# |    total_timesteps      | 53248          |
# | train/                  |                |
# |    approx_kl            | -1.1204975e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 7.21e+14       |
# |    n_updates            | 250            |
# |    policy_gradient_loss | -7.09e-07      |
# |    reward               | 2208187.2      |
# |    std                  | 1              |
# |    value_loss           | 1.4e+15        |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4420770.688020012
# Sharpe:  0.7958309186604624
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 551            |
# |    iterations           | 27             |
# |    time_elapsed         | 100            |
# |    total_timesteps      | 55296          |
# | train/                  |                |
# |    approx_kl            | -1.2048986e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.13e+15       |
# |    n_updates            | 260            |
# |    policy_gradient_loss | -5.43e-07      |
# |    reward               | 1509727.5      |
# |    std                  | 1              |
# |    value_loss           | 2.61e+15       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 552            |
# |    iterations           | 28             |
# |    time_elapsed         | 103            |
# |    total_timesteps      | 57344          |
# | train/                  |                |
# |    approx_kl            | -1.1903467e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 1.19e-07       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.34e+15       |
# |    n_updates            | 270            |
# |    policy_gradient_loss | -3.7e-07       |
# |    reward               | 4216716.0      |
# |    std                  | 1              |
# |    value_loss           | 2.78e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4545985.098227356
# Sharpe:  0.818481032799366
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 551            |
# |    iterations           | 29             |
# |    time_elapsed         | 107            |
# |    total_timesteps      | 59392          |
# | train/                  |                |
# |    approx_kl            | -1.3504177e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 9.99e+14       |
# |    n_updates            | 280            |
# |    policy_gradient_loss | -5.59e-07      |
# |    reward               | 2888256.2      |
# |    std                  | 1              |
# |    value_loss           | 2.02e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4742194.46842551
# Sharpe:  0.8319593943865413
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 551            |
# |    iterations           | 30             |
# |    time_elapsed         | 111            |
# |    total_timesteps      | 61440          |
# | train/                  |                |
# |    approx_kl            | -1.3184035e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 1.79e-07       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.25e+15       |
# |    n_updates            | 290            |
# |    policy_gradient_loss | -4.83e-07      |
# |    reward               | 1524362.0      |
# |    std                  | 1              |
# |    value_loss           | 2.14e+15       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 551            |
# |    iterations           | 31             |
# |    time_elapsed         | 115            |
# |    total_timesteps      | 63488          |
# | train/                  |                |
# |    approx_kl            | -1.3591489e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 5.96e-08       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.61e+15       |
# |    n_updates            | 300            |
# |    policy_gradient_loss | -3.49e-07      |
# |    reward               | 4912586.0      |
# |    std                  | 1              |
# |    value_loss           | 3.09e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4758996.700114379
# Sharpe:  0.833884719041882
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 551            |
# |    iterations           | 32             |
# |    time_elapsed         | 118            |
# |    total_timesteps      | 65536          |
# | train/                  |                |
# |    approx_kl            | -1.1728844e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.61e+15       |
# |    n_updates            | 310            |
# |    policy_gradient_loss | -3.92e-07      |
# |    reward               | 2970808.2      |
# |    std                  | 1              |
# |    value_loss           | 2.97e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4513964.605191909
# Sharpe:  0.8070105229350872
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 551            |
# |    iterations           | 33             |
# |    time_elapsed         | 122            |
# |    total_timesteps      | 67584          |
# | train/                  |                |
# |    approx_kl            | -1.2834789e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 7.54e+14       |
# |    n_updates            | 320            |
# |    policy_gradient_loss | -5.22e-07      |
# |    reward               | 1990998.0      |
# |    std                  | 1              |
# |    value_loss           | 1.55e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4690295.813426403
# Sharpe:  0.8281534219470557
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 551            |
# |    iterations           | 34             |
# |    time_elapsed         | 126            |
# |    total_timesteps      | 69632          |
# | train/                  |                |
# |    approx_kl            | -1.1670636e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.29e+15       |
# |    n_updates            | 330            |
# |    policy_gradient_loss | -4.12e-07      |
# |    reward               | 1316162.9      |
# |    std                  | 1              |
# |    value_loss           | 2.48e+15       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 551            |
# |    iterations           | 35             |
# |    time_elapsed         | 129            |
# |    total_timesteps      | 71680          |
# | train/                  |                |
# |    approx_kl            | -1.1175871e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.61e+15       |
# |    n_updates            | 340            |
# |    policy_gradient_loss | -3.31e-07      |
# |    reward               | 3918412.5      |
# |    std                  | 1              |
# |    value_loss           | 3.05e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4782122.84274106
# Sharpe:  0.8345929688524912
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 552            |
# |    iterations           | 36             |
# |    time_elapsed         | 133            |
# |    total_timesteps      | 73728          |
# | train/                  |                |
# |    approx_kl            | -1.2136297e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 1.19e-07       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 8.29e+14       |
# |    n_updates            | 350            |
# |    policy_gradient_loss | -5.53e-07      |
# |    reward               | 2542892.2      |
# |    std                  | 1              |
# |    value_loss           | 1.7e+15        |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4564679.01679948
# Sharpe:  0.8133425510113204
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 552            |
# |    iterations           | 37             |
# |    time_elapsed         | 137            |
# |    total_timesteps      | 75776          |
# | train/                  |                |
# |    approx_kl            | -1.1525117e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.15e+15       |
# |    n_updates            | 360            |
# |    policy_gradient_loss | -6.21e-07      |
# |    reward               | 1485343.9      |
# |    std                  | 1              |
# |    value_loss           | 2.28e+15       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 552            |
# |    iterations           | 38             |
# |    time_elapsed         | 140            |
# |    total_timesteps      | 77824          |
# | train/                  |                |
# |    approx_kl            | -1.2922101e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 1.79e-07       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.25e+15       |
# |    n_updates            | 370            |
# |    policy_gradient_loss | -4.57e-07      |
# |    reward               | 3972565.2      |
# |    std                  | 1              |
# |    value_loss           | 2.76e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4229770.856277949
# Sharpe:  0.7820518283551624
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 553            |
# |    iterations           | 39             |
# |    time_elapsed         | 144            |
# |    total_timesteps      | 79872          |
# | train/                  |                |
# |    approx_kl            | -1.2427336e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.03e+15       |
# |    n_updates            | 380            |
# |    policy_gradient_loss | -4.33e-07      |
# |    reward               | 2632541.2      |
# |    std                  | 1              |
# |    value_loss           | 2.07e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4267705.386032099
# Sharpe:  0.7854888208536008
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 553            |
# |    iterations           | 40             |
# |    time_elapsed         | 148            |
# |    total_timesteps      | 81920          |
# | train/                  |                |
# |    approx_kl            | -1.1670636e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 5.96e-08       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 8.22e+14       |
# |    n_updates            | 390            |
# |    policy_gradient_loss | -7.28e-07      |
# |    reward               | 1877370.8      |
# |    std                  | 1              |
# |    value_loss           | 1.53e+15       |
# --------------------------------------------

# %%
trained_ppo.save('trained_ppo.zip')

# %% [markdown]
# ### Model 3: **DDPG**

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}


model_ddpg = agent.get_model("ddpg",model_kwargs = DDPG_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:4364108.027940071
# Sharpe:  0.7815462635076222
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 209       |
# |    time_elapsed    | 55        |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | -7.84e+07 |
# |    critic_loss     | 4.03e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8679      |
# |    reward          | 4538970.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 187       |
# |    time_elapsed    | 123       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | -1.62e+08 |
# |    critic_loss     | 1.59e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20251     |
# |    reward          | 4538970.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 179       |
# |    time_elapsed    | 193       |
# |    total_timesteps | 34716     |
# | train/             |           |
# |    actor_loss      | -2.08e+08 |
# |    critic_loss     | 1.78e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31823     |
# |    reward          | 4538970.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 175       |
# |    time_elapsed    | 263       |
# |    total_timesteps | 46288     |
# | train/             |           |
# |    actor_loss      | -2.33e+08 |
# |    critic_loss     | 1.52e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43395     |
# |    reward          | 4538970.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4538970.724456399
# Sharpe:  0.8135913785007729
# =================================

# %%
trained_ddpg.save('trained_ddpg.zip')

# %% [markdown]
# ### Model 4: **SAC**

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0003,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0003, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=50000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:4387401.683906057
# Sharpe:  0.8032212566648127
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4410702.329001743
# Sharpe:  0.8058725896509364
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4410682.387629655
# Sharpe:  0.8058724758779349
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4410885.348141572
# Sharpe:  0.8058906054947578
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 98        |
# |    time_elapsed    | 117       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | -1.06e+08 |
# |    critic_loss     | 1.03e+12  |
# |    ent_coef        | 3.25      |
# |    ent_coef_loss   | -190      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 11471     |
# |    reward          | 4410885.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4410494.057265694
# Sharpe:  0.8058436616108094
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4411006.693863175
# Sharpe:  0.8059066544182606
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4413359.200695195
# Sharpe:  0.8061654988280197
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4409719.011854057
# Sharpe:  0.8057672172854389
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 94        |
# |    time_elapsed    | 244       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | -1.79e+08 |
# |    critic_loss     | 4.02e+12  |
# |    ent_coef        | 85.5      |
# |    ent_coef_loss   | -361      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 23043     |
# |    reward          | 4409719.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4415601.203140671
# Sharpe:  0.8063627139293362
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4437754.087513152
# Sharpe:  0.8087069033917038
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4407173.7572177425
# Sharpe:  0.8054745770928358
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4440723.317468614
# Sharpe:  0.808821949324536
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 95        |
# |    time_elapsed    | 364       |
# |    total_timesteps | 34716     |
# | train/             |           |
# |    actor_loss      | -2.01e+08 |
# |    critic_loss     | 5.71e+12  |
# |    ent_coef        | 1.32e+03  |
# |    ent_coef_loss   | -35.3     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 34615     |
# |    reward          | 4440723.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4389967.688653338
# Sharpe:  0.8037666783623223
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4407379.894152636
# Sharpe:  0.8049903222249549
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4363915.275685471
# Sharpe:  0.8012702222477782
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4341629.987001756
# Sharpe:  0.7978977049709288
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 95        |
# |    time_elapsed    | 484       |
# |    total_timesteps | 46288     |
# | train/             |           |
# |    actor_loss      | -2.22e+08 |
# |    critic_loss     | 6.99e+12  |
# |    ent_coef        | 1.55e+03  |
# |    ent_coef_loss   | 4.8       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 46187     |
# |    reward          | 4341630.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4354547.057456691
# Sharpe:  0.7989822180034992
# =================================

# %%
trained_sac.save('trained_sac.zip')

# %% [markdown]
# ### Model 5: **TD3**

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cuda device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=30000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:4579471.312265347
# Sharpe:  0.7941430807740805
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4941168.269040824
# Sharpe:  0.8131200730881819
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4941168.269040824
# Sharpe:  0.8131200730881819
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4941168.269040824
# Sharpe:  0.8131200730881819
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 204       |
# |    time_elapsed    | 56        |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | -4.31e+07 |
# |    critic_loss     | 3.25e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8679      |
# |    reward          | 4941168.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4941168.269040824
# Sharpe:  0.8131200730881819
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4941168.269040824
# Sharpe:  0.8131200730881819
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4941168.269040824
# Sharpe:  0.8131200730881819
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4941168.269040824
# Sharpe:  0.8131200730881819
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 182       |
# |    time_elapsed    | 127       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | -1.02e+08 |
# |    critic_loss     | 1.49e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20251     |
# |    reward          | 4941168.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4941168.269040824
# Sharpe:  0.8131200730881819
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4941168.269040824
# Sharpe:  0.8131200730881819
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4941168.269040824
# Sharpe:  0.8131200730881819
# =================================

# %%
trained_td3.save('trained_td3.zip')

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at 2019-01-01. We use the A2C model to trade Dow jones 30 stocks.

# %%
trade = data_split(df,'2020-07-01', '2021-10-31')
e_trade_gym = StockPortfolioEnv(df = trade, **env_kwargs)

# %%
trade.shape
# Out:
# (9436, 19)

# %%
df_daily_return, df_actions = DRLAgent.DRL_prediction(model=trained_a2c,
                        environment = e_trade_gym)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1402399.2494226778
# Sharpe:  1.9119615292640058
# =================================
# hit end!

# %%
df_daily_return.head()
# Out:
#          date  daily_return
# 0  2020-07-01      0.000000
# 1  2020-07-02      0.004819
# 2  2020-07-06      0.016452
# 3  2020-07-07     -0.015480
# 4  2020-07-08      0.006485

# %%
df_daily_return.to_csv('df_daily_return.csv')

# %%
df_actions.head()
# Out:
#                 AAPL      AMGN       AXP        BA       CAT       CRM  \
# date
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2020-07-02  0.039701  0.026236  0.030752  0.043605  0.038114  0.026236
# 2020-07-06  0.039702  0.026236  0.030753  0.043606  0.038115  0.026236
# 2020-07-07  0.039702  0.026236  0.030753  0.043606  0.038115  0.026236
# 2020-07-08  0.039702  0.026236  0.030753  0.043606  0.038115  0.026236
#
#                 CSCO       CVX       DIS        GS  ...       MMM       MRK  \
# date                                                ...
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  ...  0.035714  0.035714
# 2020-07-02  0.026236  0.026236  0.026236  0.026236  ...  0.071316  0.040611
# 2020-07-06  0.026236  0.026236  0.026236  0.026236  ...  0.071316  0.040610
# 2020-07-07  0.026236  0.026236  0.026236  0.026236  ...  0.071316  0.040610
# 2020-07-08  0.026236  0.026236  0.026236  0.026236  ...  0.071316  0.040610
#
#                 MSFT       NKE        PG       TRV       UNH        VZ  \
# date
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2020-07-02  0.065329  0.071316  0.026236  0.071316  0.026236  0.026236
# 2020-07-06  0.065328  0.071316  0.026236  0.071316  0.026236  0.026236
# 2020-07-07  0.065328  0.071316  0.026236  0.071316  0.026236  0.026236
# 2020-07-08  0.065328  0.071316  0.026236  0.071316  0.026236  0.026236
#
#                  WBA       WMT
# date
# 2020-07-01  0.035714  0.035714
# 2020-07-02  0.039041  0.026236
# 2020-07-06  0.039042  0.026236
# 2020-07-07  0.039042  0.026236
# 2020-07-08  0.039042  0.026236
#
# [5 rows x 28 columns]

# %%
df_actions.to_csv('df_actions.csv')

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
from pyfolio import timeseries
DRL_strat = convert_daily_return_to_pyfolio_ts(df_daily_return)
perf_func = timeseries.perf_stats 
perf_stats_all = perf_func( returns=DRL_strat, 
                              factor_returns=DRL_strat, 
                                positions=None, transactions=None, turnover_denom="AGB")
# Out:
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()

# %%
print("==============DRL Strategy Stats===========")
perf_stats_all
# Out:
# ==============DRL Strategy Stats===========
# Annual return          0.287736
# Cumulative returns     0.402399
# Annual volatility      0.137244
# Sharpe ratio           1.911962
# Calmar ratio           3.774671
# Stability              0.914023
# Max drawdown          -0.076228
# Omega ratio            1.371956
# Sortino ratio          2.897786
# Skew                  -0.195364
# Kurtosis               0.930774
# Tail ratio             1.039031
# Daily value at risk   -0.016250
# Alpha                  0.000000
# Beta                   1.000000
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_daily_return.loc[0,'date'],
        end = df_daily_return.loc[len(df_daily_return)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (336, 8)
# Annual return          0.279047
# Cumulative returns     0.388402
# Annual volatility      0.139129
# Sharpe ratio           1.844560
# Calmar ratio           3.124551
# Stability              0.918675
# Max drawdown          -0.089308
# Omega ratio            1.358960
# Sortino ratio          2.734872
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.052781
# Daily value at risk   -0.016510
# dtype: float64
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
# %matplotlib inline

baseline_df = get_baseline(
        ticker='^DJI', start=df_daily_return.loc[0,'date'], end='2021-11-01'
    )

baseline_returns = get_daily_return(baseline_df, value_col_name="close")

with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(returns = DRL_strat,
                                       benchmark_rets=baseline_returns, set_context=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (337, 8)
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_df = data_df.append(temp_df)
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>16</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>28.774%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>40.24%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.724%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.91</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>3.77</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.91</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-7.623%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.37</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.90</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.20</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.04</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.625%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.97</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7.62</td>
#       <td>2020-09-02</td>
#       <td>2020-10-30</td>
#       <td>2020-11-09</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5.51</td>
#       <td>2021-08-16</td>
#       <td>2021-09-30</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.05</td>
#       <td>2021-06-04</td>
#       <td>2021-06-18</td>
#       <td>2021-06-30</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.29</td>
#       <td>2021-01-21</td>
#       <td>2021-01-29</td>
#       <td>2021-02-05</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.25</td>
#       <td>2021-05-07</td>
#       <td>2021-05-12</td>
#       <td>2021-06-04</td>
#       <td>21</td>
#     </tr>
#   </tbody>
# </table>
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/plotting.py:805: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   oos_cum_returns = pd.Series([])
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/plotting.py:805: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   oos_cum_returns = pd.Series([])
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/plotting.py:805: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   oos_cum_returns = pd.Series([])
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:541: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   out = pd.Series(index=returns.index)
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:541: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   out = pd.Series(index=returns.index)
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:1230: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   period = returns_dupe.loc[start:end]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.10%</td>
#       <td>-3.12%</td>
#       <td>3.36%</td>
#     </tr>
#   </tbody>
# </table>
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:1230: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   period = returns_dupe.loc[start:end]

# %% [markdown]
# ## Min-Variance Portfolio Allocation

# %%
# %pip install PyPortfolioOpt
# Out:
# /bin/bash: /home/bassem/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: PyPortfolioOpt in /home/bassem/anaconda3/lib/python3.9/site-packages (1.5.3)
# Requirement already satisfied: pandas>=0.19 in /home/bassem/anaconda3/lib/python3.9/site-packages (from PyPortfolioOpt) (1.4.3)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /home/bassem/anaconda3/lib/python3.9/site-packages (from PyPortfolioOpt) (1.22.4)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.10 in /home/bassem/anaconda3/lib/python3.9/site-packages (from PyPortfolioOpt) (1.2.1)
# Requirement already satisfied: scipy<2.0,>=1.3 in /home/bassem/anaconda3/lib/python3.9/site-packages (from PyPortfolioOpt) (1.7.3)
# Requirement already satisfied: osqp>=0.4.1 in /home/bassem/anaconda3/lib/python3.9/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.6.2.post5)
# Requirement already satisfied: scs>=1.1.6 in /home/bassem/anaconda3/lib/python3.9/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (3.2.0)
# Requirement already satisfied: ecos>=2 in /home/bassem/anaconda3/lib/python3.9/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (2.0.10)
# Requirement already satisfied: qdldl in /home/bassem/anaconda3/lib/python3.9/site-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.1.5.post2)
# Requirement already satisfied: pytz>=2020.1 in /home/bassem/anaconda3/lib/python3.9/site-packages (from pandas>=0.19->PyPortfolioOpt) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/bassem/anaconda3/lib/python3.9/site-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/bassem/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.19->PyPortfolioOpt) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models

# %%
unique_tic = trade.tic.unique()
unique_trade_date = trade.date.unique()

# %%
df.head()
# Out:
#          date       open       high        low      close      adjcp  \
# 0  2008-12-31   3.070357   3.133571   3.047857   3.048214   2.606278
# 1  2008-12-31  57.110001  58.220001  57.060001  57.750000  43.924454
# 2  2008-12-31  17.969999  18.750000  17.910000  18.549999  14.852881
# 3  2008-12-31  41.590000  43.049999  41.500000  42.669998  32.005886
# 4  2008-12-31  43.700001  45.099998  43.700001  44.669998  30.628826
#
#       volume   tic  day      macd    boll_ub    boll_lb     rsi_30  \
# 0  607541200  AAPL    2 -0.097446   3.649552   2.895305  42.254771
# 1    6287200  AMGN    2  0.216368  58.947401  56.388599  51.060614
# 2    9625600   AXP    2 -1.191668  23.723023  16.106977  42.521170
# 3    5443100    BA    2 -0.391219  42.894634  38.486366  47.290375
# 4    6277400   CAT    2  0.979845  45.785565  38.404435  51.073052
#
#        cci_30      dx_30  close_30_sma  close_60_sma  \
# 0  -80.847207  16.129793      3.243631      3.375887
# 1   51.895357  10.432018     56.671334     56.044333
# 2  -74.811722  25.776759     20.030000     22.412000
# 3  157.922391   5.366299     40.432000     43.304500
# 4   98.904653  26.331746     40.266000     39.918333
#
#                                             cov_list  \
# 0  [[0.001348968986171653, 0.00042841264280825875...
# 1  [[0.001348968986171653, 0.00042841264280825875...
# 2  [[0.001348968986171653, 0.00042841264280825875...
# 3  [[0.001348968986171653, 0.00042841264280825875...
# 4  [[0.001348968986171653, 0.00042841264280825875...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 1  tic             AAPL      AMGN       AXP      ...
# 2  tic             AAPL      AMGN       AXP      ...
# 3  tic             AAPL      AMGN       AXP      ...
# 4  tic             AAPL      AMGN       AXP      ...

# %%
#calculate_portfolio_minimum_variance
portfolio = pd.DataFrame(index = range(1), columns = unique_trade_date)
initial_capital = 1000000
portfolio.loc[0,unique_trade_date[0]] = initial_capital

for i in range(len( unique_trade_date)-1):
    df_temp = df[df.date==unique_trade_date[i]].reset_index(drop=True)
    df_temp_next = df[df.date==unique_trade_date[i+1]].reset_index(drop=True)
    #Sigma = risk_models.sample_cov(df_temp.return_list[0])
    #calculate covariance matrix
    Sigma = df_temp.return_list[0].cov()
    #portfolio allocation
    ef_min_var = EfficientFrontier(None, Sigma,weight_bounds=(0, 0.1))
    #minimum variance
    raw_weights_min_var = ef_min_var.min_volatility()
    #get weights
    cleaned_weights_min_var = ef_min_var.clean_weights()
    
    #current capital
    cap = portfolio.iloc[0, i]
    #current cash invested for each stock
    current_cash = [element * cap for element in list(cleaned_weights_min_var.values())]
    # current held shares
    current_shares = list(np.array(current_cash)
                                      / np.array(df_temp.close))
    # next time period price
    next_price = np.array(df_temp_next.close)
    ##next_price * current share to calculate next total account value 
    portfolio.iloc[0, i+1] = np.dot(current_shares, next_price)
    
portfolio=portfolio.T
portfolio.columns = ['account_value']

# %%
portfolio.head()
# Out:
#              account_value
# 2020-07-01         1000000
# 2020-07-02  1005234.883501
# 2020-07-06  1014933.780399
# 2020-07-07  1014238.666671
# 2020-07-08  1012674.038646

# %%
a2c_cumpod =(df_daily_return.daily_return+1).cumprod()-1

# %%
min_var_cumpod =(portfolio.account_value.pct_change()+1).cumprod()-1

# %%
dji_cumpod =(baseline_returns+1).cumprod()-1

# %% [markdown]
# ## Plotly: DRL, Min-Variance, DJIA

# %%
# %pip install plotly
# Out:
# /bin/bash: /home/bassem/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: plotly in /home/bassem/anaconda3/lib/python3.9/site-packages (5.6.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/bassem/anaconda3/lib/python3.9/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /home/bassem/anaconda3/lib/python3.9/site-packages (from plotly) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime as dt

import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go

# %%
time_ind = pd.Series(df_daily_return.date)

# %%
trace0_portfolio = go.Scatter(x = time_ind, y = a2c_cumpod, mode = 'lines', name = 'A2C (Portfolio Allocation)')

trace1_portfolio = go.Scatter(x = time_ind, y = dji_cumpod, mode = 'lines', name = 'DJIA')
trace2_portfolio = go.Scatter(x = time_ind, y = min_var_cumpod, mode = 'lines', name = 'Min-Variance')
#trace3_portfolio = go.Scatter(x = time_ind, y = ddpg_cumpod, mode = 'lines', name = 'DDPG')
#trace4_portfolio = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')
#trace5_portfolio = go.Scatter(x = time_ind, y = min_cumpod, mode = 'lines', name = 'Min-Variance')

#trace4 = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')

#trace2 = go.Scatter(x = time_ind, y = portfolio_cost_minv, mode = 'lines', name = 'Min-Variance')
#trace3 = go.Scatter(x = time_ind, y = spx_value, mode = 'lines', name = 'SPX')

# %%
fig = go.Figure()
fig.add_trace(trace0_portfolio)

fig.add_trace(trace1_portfolio)

fig.add_trace(trace2_portfolio)



fig.update_layout(
    legend=dict(
        x=0,
        y=1,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=15,
            color="black"
        ),
        bgcolor="White",
        bordercolor="white",
        borderwidth=2
        
    ),
)
#fig.update_layout(legend_orientation="h")
fig.update_layout(title={
        #'text': "Cumulative Return using FinRL",
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
#with Transaction cost
#fig.update_layout(title =  'Quarterly Trade Date')
fig.update_layout(
#    margin=dict(l=20, r=20, t=20, b=20),

    paper_bgcolor='rgba(1,1,0,0)',
    plot_bgcolor='rgba(1, 1, 0, 0)',
    #xaxis_title="Date",
    yaxis_title="Cumulative Return",
xaxis={'type': 'date', 
       'tick0': time_ind[0], 
        'tickmode': 'linear', 
       'dtick': 86400000.0 *80}

)
fig.update_xaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')

fig.show()
