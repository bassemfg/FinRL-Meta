# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL/blob/master/tutorials/advanced/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Portfolio Allocation
#
# Tutorials to use OpenAI DRL to perform portfolio allocation in one Jupyter Notebook | Presented at NeurIPS 2020: Deep RL Workshop
#
# * This blog is based on our paper: FinRL: A Deep Reinforcement Learning Library for Automated Stock Trading in Quantitative Finance, presented at NeurIPS 2020: Deep RL Workshop.
# * Check out medium blog for detailed explanations:
# * Please report any issues to our Github: https://github.com/AI4Finance-Foundation/FinRL/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for portfolio alloacation. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A represents the weight of a stock in the porfolio: a ∈ (-1,1). Assume our stock pool includes N stocks, we can use a list [a<sub>1</sub>, a<sub>2</sub>, ... , a<sub>N</sub>] to determine the weight for each stock in the porfotlio, where a<sub>i</sub> ∈ (-1,1), a<sub>1</sub>+ a<sub>2</sub>+...+a<sub>N</sub>=1. For example, "The weight of AAPL in the portfolio is 10%." is [0.1 , ...].
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
      
# install finrl library
#%pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git
# Out:
# Num GPUs Available:  1
# 2022-07-10 16:48:30.330566: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-10 16:48:30.420778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-10 16:48:30.420962: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')
# %matplotlib inline
import datetime

from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline,convert_daily_return_to_pyfolio_ts
from finrl.meta.data_processor import DataProcessor
import sys
sys.path.append("../FinRL-Library")

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
dp = YahooFinanceProcessor()
df = dp.download_data(start_date = '2008-01-01',
                     end_date = '2022-07-08',
                     ticker_list = config_tickers.DOW_30_TICKER, time_interval='1D')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/data_processors/processor_yahoofinance.py:56: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Shape of DataFrame:  (106745, 9)

# %%
df.head()
# Out:
#          date       open       high        low      close      adjcp  \
# 0  2008-01-02   7.116786   7.152143   6.876786   6.958571   5.949703
# 1  2008-01-02  46.599998  47.040001  46.259998  46.599998  35.443798
# 2  2008-01-02  52.090000  52.320000  50.790001  51.040001  40.326862
# 3  2008-01-02  87.570000  87.839996  86.000000  86.620003  63.481636
# 4  2008-01-02  72.559998  72.669998  70.050003  70.629997  47.176811
#
#        volume   tic  day
# 0  1079178800  AAPL    2
# 1     7934400  AMGN    2
# 2     8053700   AXP    2
# 3     4303000    BA    2
# 4     6337800   CAT    2

# %%
df.tail()
# Out:
#               date        open        high         low       close  \
# 106740  2022-07-07  515.250000  517.299988  512.229980  514.380005
# 106741  2022-07-07  202.539993  203.429993  200.039993  202.800003
# 106742  2022-07-07   50.959999   51.060001   50.360001   50.709999
# 106743  2022-07-07   38.020000   38.279999   37.599998   38.209999
# 106744  2022-07-07  125.190002  125.529999  124.120003  125.320000
#
#              adjcp    volume  tic  day
# 106740  514.380005   2385400  UNH    3
# 106741  202.800003   4650700    V    3
# 106742   50.709999  13617100   VZ    3
# 106743   38.209999   6053300  WBA    3
# 106744  125.320000   5829100  WMT    3

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    use_turbulence=False,
                    user_defined_feature = False)

df = fe.preprocess_data(df)
# Out:
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/preprocessors.py:158: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Successfully added technical indicators

# %%
df.shape
# Out:
# (102312, 17)

# %%
df.tail()
# Out:
#               date        open        high         low       close  \
# 87695   2022-07-07  172.000000  173.210007  169.419998  169.630005
# 91349   2022-07-07  515.250000  517.299988  512.229980  514.380005
# 95003   2022-07-07   50.959999   51.060001   50.360001   50.709999
# 98657   2022-07-07   38.020000   38.279999   37.599998   38.209999
# 102311  2022-07-07  125.190002  125.529999  124.120003  125.320000
#
#              adjcp    volume  tic  day      macd     boll_ub     boll_lb  \
# 87695   169.630005   1155100  TRV    3 -0.886722  174.834748  159.134253
# 91349   514.380005   2385400  UNH    3  6.716677  534.408385  448.863618
# 95003    50.709999  13617100   VZ    3  0.245610   52.495084   48.700916
# 98657    38.209999   6053300  WBA    3 -1.096211   43.090125   37.322874
# 102311  125.320000   5829100  WMT    3 -1.507148  125.965190  118.004810
#
#            rsi_30      cci_30      dx_30  close_30_sma  close_60_sma
# 87695   48.817759   11.458670   2.540311    170.103000    172.608834
# 91349   54.534138  116.639524   6.105986    493.073000    500.552668
# 95003   49.866484   -3.695299   2.338788     50.798333     50.412167
# 98657   39.090158 -137.499066  40.492020     41.182333     42.547333
# 102311  43.980979   60.666390   0.974151    123.227667    135.868833

# %% [markdown]
# ## Add covariance matrix as states

# %%
# add covariance matrix as states
df=df.sort_values(['date','tic'],ignore_index=True)
df.index = df.date.factorize()[0]

cov_list = []
return_list = []

# look back is one year
lookback=252
for i in range(lookback,len(df.index.unique())):
  data_lookback = df.loc[i-lookback:i,:]
  price_lookback=data_lookback.pivot_table(index = 'date',columns = 'tic', values = 'close')
  return_lookback = price_lookback.pct_change().dropna()
  return_list.append(return_lookback)

  covs = return_lookback.cov().values 
  cov_list.append(covs)

  
df_cov = pd.DataFrame({'date':df.date.unique()[lookback:],'cov_list':cov_list,'return_list':return_list})
df = df.merge(df_cov, on='date')
df = df.sort_values(['date','tic']).reset_index(drop=True)

# %%
df.shape
# Out:
# (95256, 19)

# %%
df.tail()
# Out:
#              date        open        high         low       close       adjcp  \
# 95251  2022-07-07  172.000000  173.210007  169.419998  169.630005  169.630005
# 95252  2022-07-07  515.250000  517.299988  512.229980  514.380005  514.380005
# 95253  2022-07-07   50.959999   51.060001   50.360001   50.709999   50.709999
# 95254  2022-07-07   38.020000   38.279999   37.599998   38.209999   38.209999
# 95255  2022-07-07  125.190002  125.529999  124.120003  125.320000  125.320000
#
#          volume  tic  day      macd     boll_ub     boll_lb     rsi_30  \
# 95251   1155100  TRV    3 -0.886722  174.834748  159.134253  48.817759
# 95252   2385400  UNH    3  6.716677  534.408385  448.863618  54.534138
# 95253  13617100   VZ    3  0.245610   52.495084   48.700916  49.866484
# 95254   6053300  WBA    3 -1.096211   43.090125   37.322874  39.090158
# 95255   5829100  WMT    3 -1.507148  125.965190  118.004810  43.980979
#
#            cci_30      dx_30  close_30_sma  close_60_sma  \
# 95251   11.458670   2.540311    170.103000    172.608834
# 95252  116.639524   6.105986    493.073000    500.552668
# 95253   -3.695299   2.338788     50.798333     50.412167
# 95254 -137.499066  40.492020     41.182333     42.547333
# 95255   60.666390   0.974151    123.227667    135.868833
#
#                                                 cov_list  \
# 95251  [[0.000355369406262064, 6.709492164908973e-05,...
# 95252  [[0.000355369406262064, 6.709492164908973e-05,...
# 95253  [[0.000355369406262064, 6.709492164908973e-05,...
# 95254  [[0.000355369406262064, 6.709492164908973e-05,...
# 95255  [[0.000355369406262064, 6.709492164908973e-05,...
#
#                                              return_list
# 95251  tic             AAPL      AMGN       AXP      ...
# 95252  tic             AAPL      AMGN       AXP      ...
# 95253  tic             AAPL      AMGN       AXP      ...
# 95254  tic             AAPL      AMGN       AXP      ...
# 95255  tic             AAPL      AMGN       AXP      ...

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.

# %% [markdown]
# ## Training data split: 2009-01-01 to 2020-07-01

# %%
train = data_split(df, '2009-01-01','2022-01-01')
#trade = data_split(df, '2020-01-01', config.END_DATE)

# %%
train.tail()
# Out:
#             date        open        high         low       close       adjcp  \
# 3272  2021-12-31  156.529999  157.110001  156.110001  156.429993  154.790390
# 3272  2021-12-31  504.140015  506.869995  502.040009  502.140015  498.879364
# 3272  2021-12-31   52.200001   52.310001   51.880001   51.959999   50.093552
# 3272  2021-12-31   51.900002   52.419998   51.830002   52.160000   51.039719
# 3272  2021-12-31  143.199997  145.039993  142.919998  144.690002  143.610535
#
#         volume  tic  day       macd     boll_ub     boll_lb     rsi_30  \
# 3272    682400  TRV    4   0.420046  160.884117  149.742880  50.625398
# 3272   1695400  UNH    4  13.137960  516.875955  453.281046  66.629576
# 3272  15911400   VZ    4   0.228331   53.945828   49.535172  48.176436
# 3272   3406700  WBA    4   1.079008   52.675494   46.794505  60.017034
# 3272   5982600  WMT    4  -0.016457  146.288269  135.744731  52.497071
#
#           cci_30      dx_30  close_30_sma  close_60_sma  \
# 3272   45.695851   3.793566    154.652665    156.461000
# 3272  105.477087  43.324128    471.745334    456.724166
# 3272   41.040587   5.899357     51.536333     52.020834
# 3272  137.592584  39.560748     48.531666     48.529000
# 3272   75.690952  11.277835    141.459333    143.651499
#
#                                                cov_list  \
# 3272  [[0.00025012279428627757, 5.0597372543283695e-...
# 3272  [[0.00025012279428627757, 5.0597372543283695e-...
# 3272  [[0.00025012279428627757, 5.0597372543283695e-...
# 3272  [[0.00025012279428627757, 5.0597372543283695e-...
# 3272  [[0.00025012279428627757, 5.0597372543283695e-...
#
#                                             return_list
# 3272  tic             AAPL      AMGN       AXP      ...
# 3272  tic             AAPL      AMGN       AXP      ...
# 3272  tic             AAPL      AMGN       AXP      ...
# 3272  tic             AAPL      AMGN       AXP      ...
# 3272  tic             AAPL      AMGN       AXP      ...

# %% [markdown]
# ## Environment for Portfolio Allocation

# %%
import numpy as np
import pandas as pd
from gym.utils import seeding
import gym
from gym import spaces
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv


class StockPortfolioEnv(gym.Env):
    """A single stock trading environment for OpenAI gym

    Attributes
    ----------
        df: DataFrame
            input data
        stock_dim : int
            number of unique stocks
        hmax : int
            maximum number of shares to trade
        initial_amount : int
            start money
        transaction_cost_pct: float
            transaction cost percentage per trade
        reward_scaling: float
            scaling factor for reward, good for training
        state_space: int
            the dimension of input features
        action_space: int
            equals stock dimension
        tech_indicator_list: list
            a list of technical indicator names
        turbulence_threshold: int
            a threshold to control risk aversion
        day: int
            an increment number to control date

    Methods
    -------
    _sell_stock()
        perform sell action based on the sign of the action
    _buy_stock()
        perform buy action based on the sign of the action
    step()
        at each step the agent will return actions, then 
        we will calculate the reward, and return the next observation.
    reset()
        reset the environment
    render()
        use render to return other functions
    save_asset_memory()
        return account value at each time step
    save_action_memory()
        return actions/positions at each time step
        

    """
    metadata = {'render.modes': ['human']}

    def __init__(self, 
                df,
                stock_dim,
                hmax,
                initial_amount,
                transaction_cost_pct,
                reward_scaling,
                state_space,
                action_space,
                tech_indicator_list,
                turbulence_threshold=None,
                lookback=252,
                day = 0):
        #super(StockEnv, self).__init__()
        #money = 10 , scope = 1
        self.day = day
        self.lookback=lookback
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.transaction_cost_pct =transaction_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list

        # action_space normalization and shape is self.stock_dim
        self.action_space = spaces.Box(low = 0, high = 1,shape = (self.action_space,)) 
        # Shape = (34, 30)
        # covariance matrix + technical indicators
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape = (self.state_space+len(self.tech_indicator_list),self.state_space))

        # load data from a pandas dataframe
        self.data = self.df.loc[self.day,:]
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        self.terminal = False     
        self.turbulence_threshold = turbulence_threshold        
        # initalize state: inital portfolio return + individual stock return + individual weights
        self.portfolio_value = self.initial_amount

        # memorize portfolio value each step
        self.asset_memory = [self.initial_amount]
        # memorize portfolio return each step
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]]

        
    def step(self, actions):
        # print(self.day)
        self.terminal = self.day >= len(self.df.index.unique())-1
        # print(actions)

        if self.terminal:
            df = pd.DataFrame(self.portfolio_return_memory)
            df.columns = ['daily_return']
            plt.plot(df.daily_return.cumsum(),'r')
            plt.savefig('results/cumulative_reward.png')
            plt.close()
            
            plt.plot(self.portfolio_return_memory,'r')
            plt.savefig('results/rewards.png')
            plt.close()

            print("=================================")
            print("begin_total_asset:{}".format(self.asset_memory[0]))           
            print("end_total_asset:{}".format(self.portfolio_value))

            df_daily_return = pd.DataFrame(self.portfolio_return_memory)
            df_daily_return.columns = ['daily_return']
            if df_daily_return['daily_return'].std() !=0:
              sharpe = (252**0.5)*df_daily_return['daily_return'].mean()/ \
                       df_daily_return['daily_return'].std()
              print("Sharpe: ",sharpe)
            print("=================================")
            
            return self.state, self.reward, self.terminal,{}

        else:
            #print("Model actions: ",actions)
            # actions are the portfolio weight
            # normalize to sum of 1
            #if (np.array(actions) - np.array(actions).min()).sum() != 0:
            #  norm_actions = (np.array(actions) - np.array(actions).min()) / (np.array(actions) - np.array(actions).min()).sum()
            #else:
            #  norm_actions = actions
            weights = self.softmax_normalization(actions) 
            #print("Normalized actions: ", weights)
            self.actions_memory.append(weights)
            last_day_memory = self.data

            #load next state
            self.day += 1
            self.data = self.df.loc[self.day,:]
            self.covs = self.data['cov_list'].values[0]
            self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
            #print(self.state)
            # calcualte portfolio return
            # individual stocks' return * weight
            portfolio_return = sum(((self.data.close.values / last_day_memory.close.values)-1)*weights)
            # update portfolio value
            new_portfolio_value = self.portfolio_value*(1+portfolio_return)
            self.portfolio_value = new_portfolio_value

            # save into memory
            self.portfolio_return_memory.append(portfolio_return)
            self.date_memory.append(self.data.date.unique()[0])            
            self.asset_memory.append(new_portfolio_value)

            # the reward is the new portfolio value or end portfolo value
            self.reward = new_portfolio_value 
            #print("Step reward: ", self.reward)
            #self.reward = self.reward*self.reward_scaling

        return self.state, self.reward, self.terminal, {}

    def reset(self):
        self.asset_memory = [self.initial_amount]
        self.day = 0
        self.data = self.df.loc[self.day,:]
        # load states
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        self.portfolio_value = self.initial_amount
        #self.cost = 0
        #self.trades = 0
        self.terminal = False 
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]] 
        return self.state
    
    def render(self, mode='human'):
        return self.state
        
    def softmax_normalization(self, actions):
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator/denominator
        return softmax_output

    
    def save_asset_memory(self):
        date_list = self.date_memory
        portfolio_return = self.portfolio_return_memory
        #print(len(date_list))
        #print(len(asset_list))
        df_account_value = pd.DataFrame({'date':date_list,'daily_return':portfolio_return})
        return df_account_value

    def save_action_memory(self):
        # date and close price length must match actions length
        date_list = self.date_memory
        df_date = pd.DataFrame(date_list)
        df_date.columns = ['date']
        
        action_list = self.actions_memory
        df_actions = pd.DataFrame(action_list)
        df_actions.columns = self.data.tic.values
        df_actions.index = df_date.date
        #df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %%
stock_dimension = len(train.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 28, State Space: 28

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "transaction_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": config.INDICATORS, 
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4
    
}

e_train_gym = StockPortfolioEnv(df = train, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
# initialize
agent = DRLAgent(env = env_train)

# %% [markdown]
# ### Model 1: **A2C**

# %%
agent = DRLAgent(env = env_train)

A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)
# Out:
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0002}
# Using cuda device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000)
# Out:
# -------------------------------------
# | time/                 |           |
# |    fps                | 452       |
# |    iterations         | 100       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 99        |
# |    policy_loss        | 1.91e+08  |
# |    reward             | 1560990.6 |
# |    std                | 0.996     |
# |    value_loss         | 2.57e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 450       |
# |    iterations         | 200       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 199       |
# |    policy_loss        | 2.19e+08  |
# |    reward             | 1897677.5 |
# |    std                | 0.996     |
# |    value_loss         | 3.8e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 446       |
# |    iterations         | 300       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 299       |
# |    policy_loss        | 3.43e+08  |
# |    reward             | 2668284.2 |
# |    std                | 0.995     |
# |    value_loss         | 7.96e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 449       |
# |    iterations         | 400       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 399       |
# |    policy_loss        | 3.67e+08  |
# |    reward             | 3122961.5 |
# |    std                | 0.994     |
# |    value_loss         | 9.8e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 450       |
# |    iterations         | 500       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -39.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 499       |
# |    policy_loss        | 4.61e+08  |
# |    reward             | 4012605.2 |
# |    std                | 0.994     |
# |    value_loss         | 1.81e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 452       |
# |    iterations         | 600       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 599       |
# |    policy_loss        | 6e+08     |
# |    reward             | 5410586.0 |
# |    std                | 0.993     |
# |    value_loss         | 3.03e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6429676.15184572
# Sharpe:  0.8956460601031695
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 443       |
# |    iterations         | 700       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 699       |
# |    policy_loss        | 1.4e+08   |
# |    reward             | 1271289.0 |
# |    std                | 0.993     |
# |    value_loss         | 1.7e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 440       |
# |    iterations         | 800       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 799       |
# |    policy_loss        | 1.79e+08  |
# |    reward             | 1526111.1 |
# |    std                | 0.993     |
# |    value_loss         | 2.6e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 442       |
# |    iterations         | 900       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 899       |
# |    policy_loss        | 2.73e+08  |
# |    reward             | 2317963.0 |
# |    std                | 0.993     |
# |    value_loss         | 5.55e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 441       |
# |    iterations         | 1000      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 999       |
# |    policy_loss        | 3.34e+08  |
# |    reward             | 2747591.0 |
# |    std                | 0.992     |
# |    value_loss         | 8.28e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 439       |
# |    iterations         | 1100      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1099      |
# |    policy_loss        | 4.08e+08  |
# |    reward             | 3636057.8 |
# |    std                | 0.992     |
# |    value_loss         | 1.4e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 438       |
# |    iterations         | 1200      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1199      |
# |    policy_loss        | 5.32e+08  |
# |    reward             | 4642041.0 |
# |    std                | 0.991     |
# |    value_loss         | 2.21e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 438       |
# |    iterations         | 1300      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1299      |
# |    policy_loss        | 7.01e+08  |
# |    reward             | 6048501.0 |
# |    std                | 0.991     |
# |    value_loss         | 3.9e+14   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6308224.1350847455
# Sharpe:  0.8894763413297476
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 437       |
# |    iterations         | 1400      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -39.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1399      |
# |    policy_loss        | 1.69e+08  |
# |    reward             | 1541963.6 |
# |    std                | 0.991     |
# |    value_loss         | 2.49e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 438       |
# |    iterations         | 1500      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1499      |
# |    policy_loss        | 2.28e+08  |
# |    reward             | 1936051.0 |
# |    std                | 0.99      |
# |    value_loss         | 4.08e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 439       |
# |    iterations         | 1600      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1599      |
# |    policy_loss        | 3.2e+08   |
# |    reward             | 2600139.0 |
# |    std                | 0.989     |
# |    value_loss         | 7.82e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 441       |
# |    iterations         | 1700      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1699      |
# |    policy_loss        | 3.46e+08  |
# |    reward             | 3018736.0 |
# |    std                | 0.989     |
# |    value_loss         | 9.7e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 441       |
# |    iterations         | 1800      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1799      |
# |    policy_loss        | 5.2e+08   |
# |    reward             | 4364254.5 |
# |    std                | 0.988     |
# |    value_loss         | 1.99e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 441       |
# |    iterations         | 1900      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1899      |
# |    policy_loss        | 6.15e+08  |
# |    reward             | 4811280.5 |
# |    std                | 0.988     |
# |    value_loss         | 2.49e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6405583.792341679
# Sharpe:  0.8954242955007508
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 439       |
# |    iterations         | 2000      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1999      |
# |    policy_loss        | 1.34e+08  |
# |    reward             | 1235539.0 |
# |    std                | 0.988     |
# |    value_loss         | 1.57e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 438       |
# |    iterations         | 2100      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -39.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2099      |
# |    policy_loss        | 1.77e+08  |
# |    reward             | 1484209.5 |
# |    std                | 0.987     |
# |    value_loss         | 2.24e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 438       |
# |    iterations         | 2200      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2199      |
# |    policy_loss        | 2.65e+08  |
# |    reward             | 2177336.2 |
# |    std                | 0.987     |
# |    value_loss         | 4.77e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 437       |
# |    iterations         | 2300      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2299      |
# |    policy_loss        | 2.94e+08  |
# |    reward             | 2700090.0 |
# |    std                | 0.986     |
# |    value_loss         | 7.65e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 436       |
# |    iterations         | 2400      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2399      |
# |    policy_loss        | 4.02e+08  |
# |    reward             | 3441829.5 |
# |    std                | 0.986     |
# |    value_loss         | 1.25e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 436       |
# |    iterations         | 2500      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2499      |
# |    policy_loss        | 5.1e+08   |
# |    reward             | 4310697.5 |
# |    std                | 0.986     |
# |    value_loss         | 1.97e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 436       |
# |    iterations         | 2600      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2599      |
# |    policy_loss        | 7.28e+08  |
# |    reward             | 6277698.5 |
# |    std                | 0.985     |
# |    value_loss         | 4.29e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6468947.984287071
# Sharpe:  0.8974597008471848
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 2700      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2699      |
# |    policy_loss        | 1.51e+08  |
# |    reward             | 1282959.8 |
# |    std                | 0.985     |
# |    value_loss         | 1.86e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 2800      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2799      |
# |    policy_loss        | 2.13e+08  |
# |    reward             | 1790777.4 |
# |    std                | 0.985     |
# |    value_loss         | 3.3e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 433       |
# |    iterations         | 2900      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2899      |
# |    policy_loss        | 2.84e+08  |
# |    reward             | 2463226.2 |
# |    std                | 0.985     |
# |    value_loss         | 6.84e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 433       |
# |    iterations         | 3000      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2999      |
# |    policy_loss        | 3.61e+08  |
# |    reward             | 2899585.2 |
# |    std                | 0.985     |
# |    value_loss         | 9.07e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 434       |
# |    iterations         | 3100      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3099      |
# |    policy_loss        | 4.33e+08  |
# |    reward             | 3980874.0 |
# |    std                | 0.985     |
# |    value_loss         | 1.64e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 434       |
# |    iterations         | 3200      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3199      |
# |    policy_loss        | 5.02e+08  |
# |    reward             | 4463272.5 |
# |    std                | 0.985     |
# |    value_loss         | 2.1e+14   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6129922.760609006
# Sharpe:  0.8715841858295174
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 434       |
# |    iterations         | 3300      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3299      |
# |    policy_loss        | 1.2e+08   |
# |    reward             | 1121208.5 |
# |    std                | 0.985     |
# |    value_loss         | 1.17e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 434       |
# |    iterations         | 3400      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3399      |
# |    policy_loss        | 2.03e+08  |
# |    reward             | 1772264.4 |
# |    std                | 0.984     |
# |    value_loss         | 3.35e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 434       |
# |    iterations         | 3500      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3499      |
# |    policy_loss        | 2.46e+08  |
# |    reward             | 2350944.0 |
# |    std                | 0.984     |
# |    value_loss         | 5.65e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 434       |
# |    iterations         | 3600      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3599      |
# |    policy_loss        | 3.49e+08  |
# |    reward             | 2966700.8 |
# |    std                | 0.984     |
# |    value_loss         | 9.69e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 3700      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3699      |
# |    policy_loss        | 3.86e+08  |
# |    reward             | 3483516.5 |
# |    std                | 0.983     |
# |    value_loss         | 1.31e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 3800      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3799      |
# |    policy_loss        | 5.14e+08  |
# |    reward             | 4606443.0 |
# |    std                | 0.983     |
# |    value_loss         | 2.16e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 3900      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3899      |
# |    policy_loss        | 6.73e+08  |
# |    reward             | 6042180.5 |
# |    std                | 0.983     |
# |    value_loss         | 4.03e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6519608.578171363
# Sharpe:  0.9038896417939786
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 4000      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3999      |
# |    policy_loss        | 1.61e+08  |
# |    reward             | 1298656.9 |
# |    std                | 0.982     |
# |    value_loss         | 1.8e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 4100      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4099      |
# |    policy_loss        | 2.01e+08  |
# |    reward             | 1667203.2 |
# |    std                | 0.982     |
# |    value_loss         | 3.16e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 4200      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4199      |
# |    policy_loss        | 2.74e+08  |
# |    reward             | 2442304.0 |
# |    std                | 0.981     |
# |    value_loss         | 6.21e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 4300      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4299      |
# |    policy_loss        | 3.01e+08  |
# |    reward             | 2780785.2 |
# |    std                | 0.98      |
# |    value_loss         | 7.89e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 4400      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4399      |
# |    policy_loss        | 4.52e+08  |
# |    reward             | 3805835.2 |
# |    std                | 0.98      |
# |    value_loss         | 1.53e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 4500      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4499      |
# |    policy_loss        | 4.74e+08  |
# |    reward             | 4158988.0 |
# |    std                | 0.98      |
# |    value_loss         | 1.8e+14   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5846366.921648999
# Sharpe:  0.8523084772159013
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 430      |
# |    iterations         | 4600     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -39.1    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 4599     |
# |    policy_loss        | 1.12e+08 |
# |    reward             | 983092.1 |
# |    std                | 0.979    |
# |    value_loss         | 1.02e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 4700      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4699      |
# |    policy_loss        | 1.91e+08  |
# |    reward             | 1576951.6 |
# |    std                | 0.979     |
# |    value_loss         | 2.66e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 4800      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4799      |
# |    policy_loss        | 2.5e+08   |
# |    reward             | 2024159.0 |
# |    std                | 0.98      |
# |    value_loss         | 4.29e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 4900      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4899      |
# |    policy_loss        | 2.99e+08  |
# |    reward             | 2741830.0 |
# |    std                | 0.98      |
# |    value_loss         | 7.88e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 5000      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4999      |
# |    policy_loss        | 3.42e+08  |
# |    reward             | 3044424.5 |
# |    std                | 0.98      |
# |    value_loss         | 9.88e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 5100      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -39.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5099      |
# |    policy_loss        | 4.99e+08  |
# |    reward             | 4231876.5 |
# |    std                | 0.98      |
# |    value_loss         | 1.88e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 5200      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5199      |
# |    policy_loss        | 6.16e+08  |
# |    reward             | 5521958.0 |
# |    std                | 0.98      |
# |    value_loss         | 3.21e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5943882.642819541
# Sharpe:  0.8642894909564752
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 5300      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5299      |
# |    policy_loss        | 1.67e+08  |
# |    reward             | 1445256.2 |
# |    std                | 0.979     |
# |    value_loss         | 2.22e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 5400      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5399      |
# |    policy_loss        | 2.32e+08  |
# |    reward             | 1848689.4 |
# |    std                | 0.979     |
# |    value_loss         | 3.62e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 5500      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5499      |
# |    policy_loss        | 2.72e+08  |
# |    reward             | 2489837.0 |
# |    std                | 0.978     |
# |    value_loss         | 6.66e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 5600      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5599      |
# |    policy_loss        | 2.96e+08  |
# |    reward             | 2903887.8 |
# |    std                | 0.977     |
# |    value_loss         | 8.57e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 5700      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5699      |
# |    policy_loss        | 4.99e+08  |
# |    reward             | 3985113.2 |
# |    std                | 0.977     |
# |    value_loss         | 1.7e+14   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 432       |
# |    iterations         | 5800      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5799      |
# |    policy_loss        | 5.54e+08  |
# |    reward             | 3751832.5 |
# |    std                | 0.977     |
# |    value_loss         | 2.21e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6412110.844068603
# Sharpe:  0.8963372955372209
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 5900      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -39.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5899      |
# |    policy_loss        | 9.1e+07   |
# |    reward             | 750621.25 |
# |    std                | 0.977     |
# |    value_loss         | 7.19e+12  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 6000      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5999      |
# |    policy_loss        | 1.89e+08  |
# |    reward             | 1559417.2 |
# |    std                | 0.976     |
# |    value_loss         | 2.71e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 6100      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6099      |
# |    policy_loss        | 2.72e+08  |
# |    reward             | 1920787.9 |
# |    std                | 0.976     |
# |    value_loss         | 4.07e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 6200      |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6199      |
# |    policy_loss        | 3.08e+08  |
# |    reward             | 2679512.8 |
# |    std                | 0.976     |
# |    value_loss         | 7.47e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 6300      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6299      |
# |    policy_loss        | 3.66e+08  |
# |    reward             | 3082858.5 |
# |    std                | 0.976     |
# |    value_loss         | 9.73e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 6400      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6399      |
# |    policy_loss        | 4.62e+08  |
# |    reward             | 3850030.2 |
# |    std                | 0.976     |
# |    value_loss         | 1.56e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 6500      |
# |    time_elapsed       | 75        |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6499      |
# |    policy_loss        | 6.19e+08  |
# |    reward             | 5082703.0 |
# |    std                | 0.975     |
# |    value_loss         | 2.7e+14   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5789629.777365541
# Sharpe:  0.8541456963620195
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 6600      |
# |    time_elapsed       | 76        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6599      |
# |    policy_loss        | 1.51e+08  |
# |    reward             | 1257809.0 |
# |    std                | 0.976     |
# |    value_loss         | 1.81e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 6700      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6699      |
# |    policy_loss        | 1.93e+08  |
# |    reward             | 1724782.0 |
# |    std                | 0.976     |
# |    value_loss         | 3.03e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 6800      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6799      |
# |    policy_loss        | 2.92e+08  |
# |    reward             | 2410173.2 |
# |    std                | 0.976     |
# |    value_loss         | 6.2e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 6900      |
# |    time_elapsed       | 79        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6899      |
# |    policy_loss        | 3.33e+08  |
# |    reward             | 2645560.0 |
# |    std                | 0.975     |
# |    value_loss         | 7.94e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 7000      |
# |    time_elapsed       | 81        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6999      |
# |    policy_loss        | 4.22e+08  |
# |    reward             | 3916336.2 |
# |    std                | 0.976     |
# |    value_loss         | 1.58e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 7100      |
# |    time_elapsed       | 82        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7099      |
# |    policy_loss        | 5.83e+08  |
# |    reward             | 4825405.5 |
# |    std                | 0.976     |
# |    value_loss         | 2.46e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 7200      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7199      |
# |    policy_loss        | 7.66e+08  |
# |    reward             | 6458832.0 |
# |    std                | 0.975     |
# |    value_loss         | 4.21e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6430386.927168716
# Sharpe:  0.9034131062723472
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 7300      |
# |    time_elapsed       | 84        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7299      |
# |    policy_loss        | 1.79e+08  |
# |    reward             | 1535671.1 |
# |    std                | 0.975     |
# |    value_loss         | 2.49e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 7400      |
# |    time_elapsed       | 85        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7399      |
# |    policy_loss        | 2.16e+08  |
# |    reward             | 1893400.4 |
# |    std                | 0.975     |
# |    value_loss         | 3.71e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 7500      |
# |    time_elapsed       | 87        |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7499      |
# |    policy_loss        | 3.44e+08  |
# |    reward             | 2726051.2 |
# |    std                | 0.974     |
# |    value_loss         | 8.52e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 7600      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7599      |
# |    policy_loss        | 3.3e+08   |
# |    reward             | 3161926.0 |
# |    std                | 0.974     |
# |    value_loss         | 1.04e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 7700      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7699      |
# |    policy_loss        | 4.81e+08  |
# |    reward             | 4499648.0 |
# |    std                | 0.973     |
# |    value_loss         | 1.96e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 7800      |
# |    time_elapsed       | 90        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7799      |
# |    policy_loss        | 6.6e+08   |
# |    reward             | 5555950.0 |
# |    std                | 0.973     |
# |    value_loss         | 3.22e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6645963.423759813
# Sharpe:  0.9219392327814517
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 429       |
# |    iterations         | 7900      |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7899      |
# |    policy_loss        | 1.46e+08  |
# |    reward             | 1290146.5 |
# |    std                | 0.973     |
# |    value_loss         | 1.78e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 8000      |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7999      |
# |    policy_loss        | 1.99e+08  |
# |    reward             | 1614129.9 |
# |    std                | 0.973     |
# |    value_loss         | 2.74e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 8100      |
# |    time_elapsed       | 94        |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -39       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8099      |
# |    policy_loss        | 3.01e+08  |
# |    reward             | 2415530.0 |
# |    std                | 0.973     |
# |    value_loss         | 6.13e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 8200      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8199      |
# |    policy_loss        | 3.36e+08  |
# |    reward             | 2961271.2 |
# |    std                | 0.972     |
# |    value_loss         | 9.19e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 8300      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8299      |
# |    policy_loss        | 3.98e+08  |
# |    reward             | 3783157.0 |
# |    std                | 0.971     |
# |    value_loss         | 1.51e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 8400      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8399      |
# |    policy_loss        | 5.27e+08  |
# |    reward             | 4622770.5 |
# |    std                | 0.97      |
# |    value_loss         | 2.24e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 8500      |
# |    time_elapsed       | 98        |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8499      |
# |    policy_loss        | 7.01e+08  |
# |    reward             | 6315433.0 |
# |    std                | 0.97      |
# |    value_loss         | 4.11e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6512851.750443407
# Sharpe:  0.911886206399766
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 8600      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -38.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8599      |
# |    policy_loss        | 1.65e+08  |
# |    reward             | 1473139.0 |
# |    std                | 0.97      |
# |    value_loss         | 2.24e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 431       |
# |    iterations         | 8700      |
# |    time_elapsed       | 100       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8699      |
# |    policy_loss        | 2.33e+08  |
# |    reward             | 1910259.2 |
# |    std                | 0.969     |
# |    value_loss         | 3.96e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 8800      |
# |    time_elapsed       | 102       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8799      |
# |    policy_loss        | 3.14e+08  |
# |    reward             | 2723085.0 |
# |    std                | 0.969     |
# |    value_loss         | 7.83e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 8900      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8899      |
# |    policy_loss        | 3.47e+08  |
# |    reward             | 2988666.5 |
# |    std                | 0.969     |
# |    value_loss         | 9.6e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 9000      |
# |    time_elapsed       | 104       |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8999      |
# |    policy_loss        | 5.02e+08  |
# |    reward             | 4364356.5 |
# |    std                | 0.968     |
# |    value_loss         | 2.01e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 9100      |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9099      |
# |    policy_loss        | 6.44e+08  |
# |    reward             | 4884782.5 |
# |    std                | 0.969     |
# |    value_loss         | 2.77e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6563777.134046324
# Sharpe:  0.9115247597748296
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 9200      |
# |    time_elapsed       | 106       |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9199      |
# |    policy_loss        | 1.27e+08  |
# |    reward             | 1228605.2 |
# |    std                | 0.968     |
# |    value_loss         | 1.51e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 9300      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9299      |
# |    policy_loss        | 1.78e+08  |
# |    reward             | 1459669.5 |
# |    std                | 0.968     |
# |    value_loss         | 2.4e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 9400      |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9399      |
# |    policy_loss        | 2.38e+08  |
# |    reward             | 2210192.5 |
# |    std                | 0.968     |
# |    value_loss         | 5.01e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 9500      |
# |    time_elapsed       | 110       |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9499      |
# |    policy_loss        | 3.11e+08  |
# |    reward             | 2675301.0 |
# |    std                | 0.967     |
# |    value_loss         | 7.4e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 9600      |
# |    time_elapsed       | 111       |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9599      |
# |    policy_loss        | 3.88e+08  |
# |    reward             | 3454896.8 |
# |    std                | 0.966     |
# |    value_loss         | 1.26e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 9700      |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9699      |
# |    policy_loss        | 5.09e+08  |
# |    reward             | 4351024.0 |
# |    std                | 0.966     |
# |    value_loss         | 2.05e+14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 430       |
# |    iterations         | 9800      |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9799      |
# |    policy_loss        | 6.46e+08  |
# |    reward             | 6023867.0 |
# |    std                | 0.966     |
# |    value_loss         | 3.93e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6263443.511453042
# Sharpe:  0.8965806757436269
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 429       |
# |    iterations         | 9900      |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -38.8     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9899      |
# |    policy_loss        | 1.7e+08   |
# |    reward             | 1366704.0 |
# |    std                | 0.966     |
# |    value_loss         | 2.11e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 429       |
# |    iterations         | 10000     |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -38.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9999      |
# |    policy_loss        | 2.12e+08  |
# |    reward             | 1864840.5 |
# |    std                | 0.966     |
# |    value_loss         | 3.6e+13   |
# -------------------------------------

# %%
trained_a2c.save('trained_a2c.zip')

# %% [markdown]
# ### Model 2: **PPO**

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.005,
    "learning_rate": 0.0001,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.0001, 'batch_size': 128}
# Using cuda device

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=80000)
# Out:
# ----------------------------------
# | time/              |           |
# |    fps             | 642       |
# |    iterations      | 1         |
# |    time_elapsed    | 3         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 3495150.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6447833.963991973
# Sharpe:  0.8915761514446813
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 555            |
# |    iterations           | 2              |
# |    time_elapsed         | 7              |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | -1.1612428e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 5.96e-08       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 7.37e+14       |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -4.2e-07       |
# |    reward               | 1801436.1      |
# |    std                  | 1              |
# |    value_loss           | 1.42e+15       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 542            |
# |    iterations           | 3              |
# |    time_elapsed         | 11             |
# |    total_timesteps      | 6144           |
# | train/                  |                |
# |    approx_kl            | -1.2601959e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 5.96e-08       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 2.12e+15       |
# |    n_updates            | 20             |
# |    policy_gradient_loss | -3.88e-07      |
# |    reward               | 4407187.5      |
# |    std                  | 1              |
# |    value_loss           | 4.11e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6105283.940912022
# Sharpe:  0.8701751803890981
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 534            |
# |    iterations           | 4              |
# |    time_elapsed         | 15             |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -1.1961674e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.4e+15        |
# |    n_updates            | 30             |
# |    policy_gradient_loss | -3.96e-07      |
# |    reward               | 2966175.5      |
# |    std                  | 1              |
# |    value_loss           | 3.06e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6928591.960613891
# Sharpe:  0.9259580775713081
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 523            |
# |    iterations           | 5              |
# |    time_elapsed         | 19             |
# |    total_timesteps      | 10240          |
# | train/                  |                |
# |    approx_kl            | -1.1204975e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 9.18e+14       |
# |    n_updates            | 40             |
# |    policy_gradient_loss | -4.81e-07      |
# |    reward               | 1371345.0      |
# |    std                  | 1              |
# |    value_loss           | 2.43e+15       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 520            |
# |    iterations           | 6              |
# |    time_elapsed         | 23             |
# |    total_timesteps      | 12288          |
# | train/                  |                |
# |    approx_kl            | -1.1641532e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 2.25e+15       |
# |    n_updates            | 50             |
# |    policy_gradient_loss | -3.89e-07      |
# |    reward               | 4033274.2      |
# |    std                  | 1              |
# |    value_loss           | 4.54e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5610586.766547858
# Sharpe:  0.8370474149891864
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 518            |
# |    iterations           | 7              |
# |    time_elapsed         | 27             |
# |    total_timesteps      | 14336          |
# | train/                  |                |
# |    approx_kl            | -1.1990778e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.04e+15       |
# |    n_updates            | 60             |
# |    policy_gradient_loss | -4.22e-07      |
# |    reward               | 2349485.0      |
# |    std                  | 1              |
# |    value_loss           | 1.97e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6376183.995908983
# Sharpe:  0.8887171213353305
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 516           |
# |    iterations           | 8             |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | -1.207809e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.49e+15      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -6.07e-07     |
# |    reward               | 890491.75     |
# |    std                  | 1             |
# |    value_loss           | 2.75e+15      |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 515            |
# |    iterations           | 9              |
# |    time_elapsed         | 35             |
# |    total_timesteps      | 18432          |
# | train/                  |                |
# |    approx_kl            | -1.2922101e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 1.79e-07       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 2.3e+15        |
# |    n_updates            | 80             |
# |    policy_gradient_loss | -2.84e-07      |
# |    reward               | 3226383.8      |
# |    std                  | 1              |
# |    value_loss           | 4.54e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5847905.569403905
# Sharpe:  0.8511737040045
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 513            |
# |    iterations           | 10             |
# |    time_elapsed         | 39             |
# |    total_timesteps      | 20480          |
# | train/                  |                |
# |    approx_kl            | -1.2223609e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 1.79e-07       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 6.44e+14       |
# |    n_updates            | 90             |
# |    policy_gradient_loss | -5.98e-07      |
# |    reward               | 1723475.0      |
# |    std                  | 1              |
# |    value_loss           | 1.26e+15       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 514            |
# |    iterations           | 11             |
# |    time_elapsed         | 43             |
# |    total_timesteps      | 22528          |
# | train/                  |                |
# |    approx_kl            | -1.1612428e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.73e+15       |
# |    n_updates            | 100            |
# |    policy_gradient_loss | -3.23e-07      |
# |    reward               | 4274639.0      |
# |    std                  | 1              |
# |    value_loss           | 3.42e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6301239.778782895
# Sharpe:  0.8883822567796414
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 512            |
# |    iterations           | 12             |
# |    time_elapsed         | 47             |
# |    total_timesteps      | 24576          |
# | train/                  |                |
# |    approx_kl            | -1.1961674e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.5e+15        |
# |    n_updates            | 110            |
# |    policy_gradient_loss | -4.46e-07      |
# |    reward               | 2840458.5      |
# |    std                  | 1              |
# |    value_loss           | 2.84e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6652324.605291564
# Sharpe:  0.9079504182174826
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 513            |
# |    iterations           | 13             |
# |    time_elapsed         | 51             |
# |    total_timesteps      | 26624          |
# | train/                  |                |
# |    approx_kl            | -1.2776582e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.38e+15       |
# |    n_updates            | 120            |
# |    policy_gradient_loss | -4.29e-07      |
# |    reward               | 1433404.2      |
# |    std                  | 1              |
# |    value_loss           | 2.45e+15       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 515           |
# |    iterations           | 14            |
# |    time_elapsed         | 55            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | -1.231092e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.98e+15      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -3.08e-07     |
# |    reward               | 4498763.5     |
# |    std                  | 1             |
# |    value_loss           | 4.29e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6875211.038953169
# Sharpe:  0.9218720250078385
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 515            |
# |    iterations           | 15             |
# |    time_elapsed         | 59             |
# |    total_timesteps      | 30720          |
# | train/                  |                |
# |    approx_kl            | -1.1728844e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 5.96e-08       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.11e+15       |
# |    n_updates            | 140            |
# |    policy_gradient_loss | -5.8e-07       |
# |    reward               | 2517665.5      |
# |    std                  | 1              |
# |    value_loss           | 2.3e+15        |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6585102.806698454
# Sharpe:  0.9016471515994997
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 514            |
# |    iterations           | 16             |
# |    time_elapsed         | 63             |
# |    total_timesteps      | 32768          |
# | train/                  |                |
# |    approx_kl            | -1.3154931e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 2.27e+15       |
# |    n_updates            | 150            |
# |    policy_gradient_loss | -3.05e-07      |
# |    reward               | 792651.4       |
# |    std                  | 1              |
# |    value_loss           | 3.65e+15       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 514            |
# |    iterations           | 17             |
# |    time_elapsed         | 67             |
# |    total_timesteps      | 34816          |
# | train/                  |                |
# |    approx_kl            | -1.1496013e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 2.11e+15       |
# |    n_updates            | 160            |
# |    policy_gradient_loss | -3.18e-07      |
# |    reward               | 3157950.0      |
# |    std                  | 1              |
# |    value_loss           | 4.71e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6111560.414546537
# Sharpe:  0.8707856097925559
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 514            |
# |    iterations           | 18             |
# |    time_elapsed         | 71             |
# |    total_timesteps      | 36864          |
# | train/                  |                |
# |    approx_kl            | -1.1612428e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 6.05e+14       |
# |    n_updates            | 170            |
# |    policy_gradient_loss | -5.63e-07      |
# |    reward               | 1699516.0      |
# |    std                  | 1              |
# |    value_loss           | 1.28e+15       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 515            |
# |    iterations           | 19             |
# |    time_elapsed         | 75             |
# |    total_timesteps      | 38912          |
# | train/                  |                |
# |    approx_kl            | -1.2456439e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.79e+15       |
# |    n_updates            | 180            |
# |    policy_gradient_loss | -5.3e-07       |
# |    reward               | 4815887.5      |
# |    std                  | 1              |
# |    value_loss           | 3.61e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6824415.5976842325
# Sharpe:  0.9167595079240951
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 515            |
# |    iterations           | 20             |
# |    time_elapsed         | 79             |
# |    total_timesteps      | 40960          |
# | train/                  |                |
# |    approx_kl            | -1.1030352e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.71e+15       |
# |    n_updates            | 190            |
# |    policy_gradient_loss | -4.33e-07      |
# |    reward               | 2580175.8      |
# |    std                  | 1              |
# |    value_loss           | 3.3e+15        |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6059859.251803345
# Sharpe:  0.8644398194667844
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 514            |
# |    iterations           | 21             |
# |    time_elapsed         | 83             |
# |    total_timesteps      | 43008          |
# | train/                  |                |
# |    approx_kl            | -1.1379598e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.35e+15       |
# |    n_updates            | 200            |
# |    policy_gradient_loss | -5.4e-07       |
# |    reward               | 1455904.5      |
# |    std                  | 1              |
# |    value_loss           | 2.6e+15        |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 515           |
# |    iterations           | 22            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | -1.207809e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.8e+15       |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -3.42e-07     |
# |    reward               | 4084880.5     |
# |    std                  | 1             |
# |    value_loss           | 3.91e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6436867.789499263
# Sharpe:  0.8903738613813253
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 513            |
# |    iterations           | 23             |
# |    time_elapsed         | 91             |
# |    total_timesteps      | 47104          |
# | train/                  |                |
# |    approx_kl            | -1.1903467e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 1.19e-07       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.06e+15       |
# |    n_updates            | 220            |
# |    policy_gradient_loss | -5.03e-07      |
# |    reward               | 2436311.2      |
# |    std                  | 1              |
# |    value_loss           | 2.22e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6778986.078920102
# Sharpe:  0.9125702634096048
# =================================
# ---------------------------------------------
# | time/                   |                 |
# |    fps                  | 513             |
# |    iterations           | 24              |
# |    time_elapsed         | 95              |
# |    total_timesteps      | 49152           |
# | train/                  |                 |
# |    approx_kl            | -1.29512046e-08 |
# |    clip_fraction        | 0               |
# |    clip_range           | 0.2             |
# |    entropy_loss         | -39.7           |
# |    explained_variance   | 5.96e-08        |
# |    learning_rate        | 0.0001          |
# |    loss                 | 1.64e+15        |
# |    n_updates            | 230             |
# |    policy_gradient_loss | -3.25e-07       |
# |    reward               | 982128.56       |
# |    std                  | 1               |
# |    value_loss           | 3.27e+15        |
# ---------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 514            |
# |    iterations           | 25             |
# |    time_elapsed         | 99             |
# |    total_timesteps      | 51200          |
# | train/                  |                |
# |    approx_kl            | -1.1728844e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 2.12e+15       |
# |    n_updates            | 240            |
# |    policy_gradient_loss | -3e-07         |
# |    reward               | 3601605.2      |
# |    std                  | 1              |
# |    value_loss           | 4.71e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6681913.531703639
# Sharpe:  0.9102636539499881
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 513           |
# |    iterations           | 26            |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | -9.895302e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 7.61e+14      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -5.93e-07     |
# |    reward               | 1791620.6     |
# |    std                  | 1             |
# |    value_loss           | 1.57e+15      |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 514            |
# |    iterations           | 27             |
# |    time_elapsed         | 107            |
# |    total_timesteps      | 55296          |
# | train/                  |                |
# |    approx_kl            | -1.2194505e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.97e+15       |
# |    n_updates            | 260            |
# |    policy_gradient_loss | -5.16e-07      |
# |    reward               | 4705939.0      |
# |    std                  | 1              |
# |    value_loss           | 4.23e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6324874.079607859
# Sharpe:  0.8897624575780789
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 514            |
# |    iterations           | 28             |
# |    time_elapsed         | 111            |
# |    total_timesteps      | 57344          |
# | train/                  |                |
# |    approx_kl            | -1.1874363e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.53e+15       |
# |    n_updates            | 270            |
# |    policy_gradient_loss | -3.9e-07       |
# |    reward               | 2752114.2      |
# |    std                  | 1              |
# |    value_loss           | 3.09e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6222736.22793964
# Sharpe:  0.8834160283191899
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 513            |
# |    iterations           | 29             |
# |    time_elapsed         | 115            |
# |    total_timesteps      | 59392          |
# | train/                  |                |
# |    approx_kl            | -1.0477379e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.24e+15       |
# |    n_updates            | 280            |
# |    policy_gradient_loss | -6.38e-07      |
# |    reward               | 1516061.5      |
# |    std                  | 1              |
# |    value_loss           | 2.39e+15       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 514            |
# |    iterations           | 30             |
# |    time_elapsed         | 119            |
# |    total_timesteps      | 61440          |
# | train/                  |                |
# |    approx_kl            | -1.1263182e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.97e+15       |
# |    n_updates            | 290            |
# |    policy_gradient_loss | -5.36e-07      |
# |    reward               | 4152110.5      |
# |    std                  | 1              |
# |    value_loss           | 4.02e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6587651.666545657
# Sharpe:  0.903248615532884
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 513           |
# |    iterations           | 31            |
# |    time_elapsed         | 123           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | -1.207809e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -39.7         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.18e+15      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -4.31e-07     |
# |    reward               | 2461403.8     |
# |    std                  | 1             |
# |    value_loss           | 2.27e+15      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6782860.225844358
# Sharpe:  0.9151749703886188
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 514            |
# |    iterations           | 32             |
# |    time_elapsed         | 127            |
# |    total_timesteps      | 65536          |
# | train/                  |                |
# |    approx_kl            | -1.1990778e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 1.79e-07       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.7e+15        |
# |    n_updates            | 310            |
# |    policy_gradient_loss | -4.85e-07      |
# |    reward               | 980758.1       |
# |    std                  | 1              |
# |    value_loss           | 3.29e+15       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 514            |
# |    iterations           | 33             |
# |    time_elapsed         | 131            |
# |    total_timesteps      | 67584          |
# | train/                  |                |
# |    approx_kl            | -1.1874363e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 1.19e-07       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 2.5e+15        |
# |    n_updates            | 320            |
# |    policy_gradient_loss | -2.79e-07      |
# |    reward               | 3609738.0      |
# |    std                  | 1              |
# |    value_loss           | 4.84e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6713439.215109796
# Sharpe:  0.9125180547170902
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 514            |
# |    iterations           | 34             |
# |    time_elapsed         | 135            |
# |    total_timesteps      | 69632          |
# | train/                  |                |
# |    approx_kl            | -1.1001248e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 7.8e+14        |
# |    n_updates            | 330            |
# |    policy_gradient_loss | -6.11e-07      |
# |    reward               | 1734220.8      |
# |    std                  | 1              |
# |    value_loss           | 1.6e+15        |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 513            |
# |    iterations           | 35             |
# |    time_elapsed         | 139            |
# |    total_timesteps      | 71680          |
# | train/                  |                |
# |    approx_kl            | -1.3184035e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.65e+15       |
# |    n_updates            | 340            |
# |    policy_gradient_loss | -4.22e-07      |
# |    reward               | 4254519.0      |
# |    std                  | 1              |
# |    value_loss           | 4.17e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5607483.678597286
# Sharpe:  0.8346343025292075
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 510            |
# |    iterations           | 36             |
# |    time_elapsed         | 144            |
# |    total_timesteps      | 73728          |
# | train/                  |                |
# |    approx_kl            | -1.3213139e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.34e+15       |
# |    n_updates            | 350            |
# |    policy_gradient_loss | -3.42e-07      |
# |    reward               | 2871210.5      |
# |    std                  | 1              |
# |    value_loss           | 2.67e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6865698.438802493
# Sharpe:  0.9215174767611638
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 509            |
# |    iterations           | 37             |
# |    time_elapsed         | 148            |
# |    total_timesteps      | 75776          |
# | train/                  |                |
# |    approx_kl            | -1.1670636e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.11e+15       |
# |    n_updates            | 360            |
# |    policy_gradient_loss | -4.77e-07      |
# |    reward               | 1620045.5      |
# |    std                  | 1              |
# |    value_loss           | 2.03e+15       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 509            |
# |    iterations           | 38             |
# |    time_elapsed         | 152            |
# |    total_timesteps      | 77824          |
# | train/                  |                |
# |    approx_kl            | -1.2369128e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 1.79e-07       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.97e+15       |
# |    n_updates            | 370            |
# |    policy_gradient_loss | -4.03e-07      |
# |    reward               | 4288096.5      |
# |    std                  | 1              |
# |    value_loss           | 4.45e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6382471.564351296
# Sharpe:  0.8888775269444673
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 509            |
# |    iterations           | 39             |
# |    time_elapsed         | 156            |
# |    total_timesteps      | 79872          |
# | train/                  |                |
# |    approx_kl            | -1.1845259e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 1.79e-07       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.24e+15       |
# |    n_updates            | 380            |
# |    policy_gradient_loss | -5.28e-07      |
# |    reward               | 2450999.8      |
# |    std                  | 1              |
# |    value_loss           | 2.41e+15       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6618054.669572286
# Sharpe:  0.9056397923369005
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 509            |
# |    iterations           | 40             |
# |    time_elapsed         | 160            |
# |    total_timesteps      | 81920          |
# | train/                  |                |
# |    approx_kl            | -1.2136297e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -39.7          |
# |    explained_variance   | 5.96e-08       |
# |    learning_rate        | 0.0001         |
# |    loss                 | 1.33e+15       |
# |    n_updates            | 390            |
# |    policy_gradient_loss | -4.66e-07      |
# |    reward               | 1055107.1      |
# |    std                  | 1              |
# |    value_loss           | 3.05e+15       |
# --------------------------------------------

# %%
trained_ppo.save('trained_ppo.zip')

# %% [markdown]
# ### Model 3: **DDPG**

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}


model_ddpg = agent.get_model("ddpg",model_kwargs = DDPG_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:6226727.26261899
# Sharpe:  0.8829800590888058
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 194       |
# |    time_elapsed    | 67        |
# |    total_timesteps | 13092     |
# | train/             |           |
# |    actor_loss      | -9.82e+07 |
# |    critic_loss     | 1.18e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9819      |
# |    reward          | 6293525.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 173       |
# |    time_elapsed    | 150       |
# |    total_timesteps | 26184     |
# | train/             |           |
# |    actor_loss      | -1.97e+08 |
# |    critic_loss     | 3.23e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22911     |
# |    reward          | 6293525.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 167       |
# |    time_elapsed    | 234       |
# |    total_timesteps | 39276     |
# | train/             |           |
# |    actor_loss      | -2.48e+08 |
# |    critic_loss     | 4.81e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 36003     |
# |    reward          | 6293525.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6293525.47935244
# Sharpe:  0.8831061773373939
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 163       |
# |    time_elapsed    | 320       |
# |    total_timesteps | 52368     |
# | train/             |           |
# |    actor_loss      | -2.73e+08 |
# |    critic_loss     | 4.49e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49095     |
# |    reward          | 6293525.5 |
# ----------------------------------

# %%
trained_ddpg.save('trained_ddpg.zip')

# %% [markdown]
# ### Model 4: **SAC**

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0003,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0003, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=50000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:6270247.744717148
# Sharpe:  0.875367396314767
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6371472.290352289
# Sharpe:  0.8741773349089339
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6371175.385361361
# Sharpe:  0.8741596516237767
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6371144.692039665
# Sharpe:  0.8741617548245573
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 90        |
# |    time_elapsed    | 144       |
# |    total_timesteps | 13092     |
# | train/             |           |
# |    actor_loss      | -1.32e+08 |
# |    critic_loss     | 1.46e+12  |
# |    ent_coef        | 5.05      |
# |    ent_coef_loss   | -247      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 12991     |
# |    reward          | 6371144.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6372190.453619129
# Sharpe:  0.8742376967679716
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6369485.128253323
# Sharpe:  0.8740885429358537
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6367518.998721127
# Sharpe:  0.8740019442208609
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6371367.855654648
# Sharpe:  0.8743696167391994
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 93        |
# |    time_elapsed    | 280       |
# |    total_timesteps | 26184     |
# | train/             |           |
# |    actor_loss      | -2.01e+08 |
# |    critic_loss     | 5.47e+12  |
# |    ent_coef        | 197       |
# |    ent_coef_loss   | -319      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 26083     |
# |    reward          | 6371368.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6361399.333670994
# Sharpe:  0.873986833344812
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6364327.514140166
# Sharpe:  0.8746165320425098
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6555493.953224502
# Sharpe:  0.888292220521821
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6289506.871237492
# Sharpe:  0.8717815308015062
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 93        |
# |    time_elapsed    | 418       |
# |    total_timesteps | 39276     |
# | train/             |           |
# |    actor_loss      | -2.41e+08 |
# |    critic_loss     | 7.78e+12  |
# |    ent_coef        | 1.79e+03  |
# |    ent_coef_loss   | -9.58     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 39175     |
# |    reward          | 6289507.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6325918.953688759
# Sharpe:  0.8737997463636257
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6398026.78206689
# Sharpe:  0.8784138418997389
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6437246.596017691
# Sharpe:  0.8806030337821109
# =================================

# %%
trained_sac.save('trained_sac.zip')

# %% [markdown]
# ### Model 5: **TD3**

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cuda device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=30000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:6564837.6989446385
# Sharpe:  0.9078127551282573
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6711881.305972394
# Sharpe:  0.9282630030559074
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6711881.305972394
# Sharpe:  0.9282630030559074
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6711881.305972394
# Sharpe:  0.9282630030559074
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 205       |
# |    time_elapsed    | 63        |
# |    total_timesteps | 13092     |
# | train/             |           |
# |    actor_loss      | -5.48e+07 |
# |    critic_loss     | 7.04e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9819      |
# |    reward          | 6711881.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6711881.305972394
# Sharpe:  0.9282630030559074
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6711881.305972394
# Sharpe:  0.9282630030559074
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6711881.305972394
# Sharpe:  0.9282630030559074
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6711881.305972394
# Sharpe:  0.9282630030559074
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 182       |
# |    time_elapsed    | 143       |
# |    total_timesteps | 26184     |
# | train/             |           |
# |    actor_loss      | -1.25e+08 |
# |    critic_loss     | 3.18e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22911     |
# |    reward          | 6711881.5 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6711881.305972394
# Sharpe:  0.9282630030559074
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6711881.305972394
# Sharpe:  0.9282630030559074
# =================================

# %%
trained_td3.save('trained_td3.zip')

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at 2019-01-01. We use the A2C model to trade Dow jones 30 stocks.

# %%
trade = data_split(df,'2020-07-01', '2021-10-31')
e_trade_gym = StockPortfolioEnv(df = trade, **env_kwargs)

# %%
trade.shape
# Out:
# (9436, 19)

# %%
df_daily_return, df_actions = DRLAgent.DRL_prediction(model=trained_a2c,
                        environment = e_trade_gym)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1378582.8268142652
# Sharpe:  1.8308098975242877
# =================================
# hit end!

# %%
df_daily_return.head()
# Out:
#          date  daily_return
# 0  2020-07-01      0.000000
# 1  2020-07-02      0.004558
# 2  2020-07-06      0.014850
# 3  2020-07-07     -0.013461
# 4  2020-07-08      0.005551

# %%
df_daily_return.to_csv('df_daily_return.csv')

# %%
df_actions.head()
# Out:
#                 AAPL      AMGN       AXP        BA       CAT       CRM  \
# date
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2020-07-02  0.025725  0.069928  0.053121  0.025725  0.025725  0.025725
# 2020-07-06  0.025725  0.069928  0.053121  0.025725  0.025725  0.025725
# 2020-07-07  0.025725  0.069928  0.053121  0.025725  0.025725  0.025725
# 2020-07-08  0.025725  0.069928  0.053121  0.025725  0.025725  0.025725
#
#                 CSCO       CVX       DIS        GS  ...       MMM       MRK  \
# date                                                ...
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  ...  0.035714  0.035714
# 2020-07-02  0.030724  0.025725  0.069928  0.025725  ...  0.025725  0.039325
# 2020-07-06  0.030724  0.025725  0.069928  0.025725  ...  0.025725  0.039325
# 2020-07-07  0.030724  0.025725  0.069928  0.025725  ...  0.025725  0.039325
# 2020-07-08  0.030724  0.025725  0.069928  0.025725  ...  0.025725  0.039325
#
#                 MSFT       NKE        PG       TRV       UNH        VZ  \
# date
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2020-07-02  0.025725  0.069928  0.025725  0.025725  0.038988  0.025725
# 2020-07-06  0.025725  0.069928  0.025725  0.025725  0.038988  0.025725
# 2020-07-07  0.025725  0.069928  0.025725  0.025725  0.038988  0.025725
# 2020-07-08  0.025725  0.069928  0.025725  0.025725  0.038988  0.025725
#
#                  WBA       WMT
# date
# 2020-07-01  0.035714  0.035714
# 2020-07-02  0.055984  0.040296
# 2020-07-06  0.055984  0.040296
# 2020-07-07  0.055984  0.040296
# 2020-07-08  0.055984  0.040296
#
# [5 rows x 28 columns]

# %%
df_actions.to_csv('df_actions.csv')

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
from pyfolio import timeseries
DRL_strat = convert_daily_return_to_pyfolio_ts(df_daily_return)
perf_func = timeseries.perf_stats 
perf_stats_all = perf_func( returns=DRL_strat, 
                              factor_returns=DRL_strat, 
                                positions=None, transactions=None, turnover_denom="AGB")
# Out:
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:724: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
print("==============DRL Strategy Stats===========")
perf_stats_all
# Out:
# ==============DRL Strategy Stats===========
# Annual return          0.271348
# Cumulative returns     0.378583
# Annual volatility      0.136246
# Sharpe ratio           1.830810
# Calmar ratio           3.216424
# Stability              0.901699
# Max drawdown          -0.084363
# Omega ratio            1.355992
# Sortino ratio          2.802226
# Skew                  -0.051724
# Kurtosis               1.670859
# Tail ratio             1.070491
# Daily value at risk   -0.016176
# Alpha                  0.000000
# Beta                   1.000000
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_daily_return.loc[0,'date'],
        end = df_daily_return.loc[len(df_daily_return)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (336, 8)
# Annual return          0.279047
# Cumulative returns     0.388402
# Annual volatility      0.139129
# Sharpe ratio           1.844560
# Calmar ratio           3.124551
# Stability              0.918675
# Max drawdown          -0.089308
# Omega ratio            1.358960
# Sortino ratio          2.734872
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.052781
# Daily value at risk   -0.016510
# dtype: float64
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:724: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
# %matplotlib inline

baseline_df = get_baseline(
        ticker='^DJI', start=df_daily_return.loc[0,'date'], end='2021-11-01'
    )

baseline_returns = get_daily_return(baseline_df, value_col_name="close")

with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(returns = DRL_strat,
                                       benchmark_rets=baseline_returns, set_context=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (337, 8)
# /home/bassem/anaconda3/lib/python3.9/site-packages/finrl/meta/preprocessor/yahoodownloader.py:54: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:724: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>16</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>27.135%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>37.858%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.625%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.83</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>3.22</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-8.436%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.36</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.80</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.05</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>1.67</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.07</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.618%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.96</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8.44</td>
#       <td>2020-09-02</td>
#       <td>2020-10-28</td>
#       <td>2020-11-09</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5.22</td>
#       <td>2021-08-16</td>
#       <td>2021-09-30</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.22</td>
#       <td>2021-05-07</td>
#       <td>2021-06-18</td>
#       <td>2021-07-02</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.60</td>
#       <td>2021-01-20</td>
#       <td>2021-01-29</td>
#       <td>2021-02-08</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.14</td>
#       <td>2021-02-24</td>
#       <td>2021-03-04</td>
#       <td>2021-03-10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/plotting.py:805: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/plotting.py:805: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/plotting.py:805: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:541: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:541: FutureWarning:
#
# The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:1230: FutureWarning:
#
# Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.10%</td>
#       <td>-3.35%</td>
#       <td>4.11%</td>
#     </tr>
#   </tbody>
# </table>
# /home/bassem/anaconda3/lib/python3.9/site-packages/pyfolio/timeseries.py:1230: FutureWarning:
#
# Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.

# %% [markdown]
# ## Min-Variance Portfolio Allocation

# %%
# %pip install PyPortfolioOpt
# Out:
# /bin/bash: /home/bassem/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: PyPortfolioOpt in /home/bassem/anaconda3/lib/python3.9/site-packages (1.5.3)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /home/bassem/anaconda3/lib/python3.9/site-packages (from PyPortfolioOpt) (1.22.4)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.10 in /home/bassem/anaconda3/lib/python3.9/site-packages (from PyPortfolioOpt) (1.2.1)
# Requirement already satisfied: scipy<2.0,>=1.3 in /home/bassem/anaconda3/lib/python3.9/site-packages (from PyPortfolioOpt) (1.7.3)
# Requirement already satisfied: pandas>=0.19 in /home/bassem/anaconda3/lib/python3.9/site-packages (from PyPortfolioOpt) (1.4.3)
# Requirement already satisfied: osqp>=0.4.1 in /home/bassem/anaconda3/lib/python3.9/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.6.2.post5)
# Requirement already satisfied: ecos>=2 in /home/bassem/anaconda3/lib/python3.9/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (2.0.10)
# Requirement already satisfied: scs>=1.1.6 in /home/bassem/anaconda3/lib/python3.9/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (3.2.0)
# Requirement already satisfied: qdldl in /home/bassem/anaconda3/lib/python3.9/site-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.1.5.post2)
# Requirement already satisfied: pytz>=2020.1 in /home/bassem/anaconda3/lib/python3.9/site-packages (from pandas>=0.19->PyPortfolioOpt) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/bassem/anaconda3/lib/python3.9/site-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/bassem/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.19->PyPortfolioOpt) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models

# %%
unique_tic = trade.tic.unique()
unique_trade_date = trade.date.unique()

# %%
df.head()
# Out:
#          date       open       high        low      close      adjcp  \
# 0  2008-12-31   3.070357   3.133571   3.047857   3.048214   2.606277
# 1  2008-12-31  57.110001  58.220001  57.060001  57.750000  43.924446
# 2  2008-12-31  17.969999  18.750000  17.910000  18.549999  14.852876
# 3  2008-12-31  41.590000  43.049999  41.500000  42.669998  32.005890
# 4  2008-12-31  43.700001  45.099998  43.700001  44.669998  30.628822
#
#       volume   tic  day      macd    boll_ub    boll_lb     rsi_30  \
# 0  607541200  AAPL    2 -0.097446   3.649552   2.895305  42.254771
# 1    6287200  AMGN    2  0.216368  58.947401  56.388599  51.060614
# 2    9625600   AXP    2 -1.191668  23.723023  16.106977  42.521170
# 3    5443100    BA    2 -0.391219  42.894634  38.486366  47.290375
# 4    6277400   CAT    2  0.979845  45.785565  38.404435  51.073052
#
#        cci_30      dx_30  close_30_sma  close_60_sma  \
# 0  -80.847207  16.129793      3.243631      3.375887
# 1   51.895357  10.432018     56.671334     56.044333
# 2  -74.811722  25.776759     20.030000     22.412000
# 3  157.922391   5.366299     40.432000     43.304500
# 4   98.904653  26.331746     40.266000     39.918333
#
#                                             cov_list  \
# 0  [[0.001348968986171653, 0.00042841264280825875...
# 1  [[0.001348968986171653, 0.00042841264280825875...
# 2  [[0.001348968986171653, 0.00042841264280825875...
# 3  [[0.001348968986171653, 0.00042841264280825875...
# 4  [[0.001348968986171653, 0.00042841264280825875...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 1  tic             AAPL      AMGN       AXP      ...
# 2  tic             AAPL      AMGN       AXP      ...
# 3  tic             AAPL      AMGN       AXP      ...
# 4  tic             AAPL      AMGN       AXP      ...

# %%
#calculate_portfolio_minimum_variance
portfolio = pd.DataFrame(index = range(1), columns = unique_trade_date)
initial_capital = 1000000
portfolio.loc[0,unique_trade_date[0]] = initial_capital

for i in range(len( unique_trade_date)-1):
    df_temp = df[df.date==unique_trade_date[i]].reset_index(drop=True)
    df_temp_next = df[df.date==unique_trade_date[i+1]].reset_index(drop=True)
    #Sigma = risk_models.sample_cov(df_temp.return_list[0])
    #calculate covariance matrix
    Sigma = df_temp.return_list[0].cov()
    #portfolio allocation
    ef_min_var = EfficientFrontier(None, Sigma,weight_bounds=(0, 0.1))
    #minimum variance
    raw_weights_min_var = ef_min_var.min_volatility()
    #get weights
    cleaned_weights_min_var = ef_min_var.clean_weights()
    
    #current capital
    cap = portfolio.iloc[0, i]
    #current cash invested for each stock
    current_cash = [element * cap for element in list(cleaned_weights_min_var.values())]
    # current held shares
    current_shares = list(np.array(current_cash)
                                      / np.array(df_temp.close))
    # next time period price
    next_price = np.array(df_temp_next.close)
    ##next_price * current share to calculate next total account value 
    portfolio.iloc[0, i+1] = np.dot(current_shares, next_price)
    
portfolio=portfolio.T
portfolio.columns = ['account_value']

# %%
portfolio.head()
# Out:
#              account_value
# 2020-07-01         1000000
# 2020-07-02  1005234.883501
# 2020-07-06  1014933.780399
# 2020-07-07  1014238.666671
# 2020-07-08  1012674.038646

# %%
a2c_cumpod =(df_daily_return.daily_return+1).cumprod()-1

# %%
min_var_cumpod =(portfolio.account_value.pct_change()+1).cumprod()-1

# %%
dji_cumpod =(baseline_returns+1).cumprod()-1

# %% [markdown]
# ## Plotly: DRL, Min-Variance, DJIA

# %%
# %pip install plotly
# Out:
# /bin/bash: /home/bassem/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: plotly in /home/bassem/anaconda3/lib/python3.9/site-packages (5.6.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/bassem/anaconda3/lib/python3.9/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /home/bassem/anaconda3/lib/python3.9/site-packages (from plotly) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime as dt

import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go

# %%
time_ind = pd.Series(df_daily_return.date)

# %%
trace0_portfolio = go.Scatter(x = time_ind, y = a2c_cumpod, mode = 'lines', name = 'A2C (Portfolio Allocation)')

trace1_portfolio = go.Scatter(x = time_ind, y = dji_cumpod, mode = 'lines', name = 'DJIA')
trace2_portfolio = go.Scatter(x = time_ind, y = min_var_cumpod, mode = 'lines', name = 'Min-Variance')
#trace3_portfolio = go.Scatter(x = time_ind, y = ddpg_cumpod, mode = 'lines', name = 'DDPG')
#trace4_portfolio = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')
#trace5_portfolio = go.Scatter(x = time_ind, y = min_cumpod, mode = 'lines', name = 'Min-Variance')

#trace4 = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')

#trace2 = go.Scatter(x = time_ind, y = portfolio_cost_minv, mode = 'lines', name = 'Min-Variance')
#trace3 = go.Scatter(x = time_ind, y = spx_value, mode = 'lines', name = 'SPX')

# %%
fig = go.Figure()
fig.add_trace(trace0_portfolio)

fig.add_trace(trace1_portfolio)

fig.add_trace(trace2_portfolio)



fig.update_layout(
    legend=dict(
        x=0,
        y=1,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=15,
            color="black"
        ),
        bgcolor="White",
        bordercolor="white",
        borderwidth=2
        
    ),
)
#fig.update_layout(legend_orientation="h")
fig.update_layout(title={
        #'text': "Cumulative Return using FinRL",
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
#with Transaction cost
#fig.update_layout(title =  'Quarterly Trade Date')
fig.update_layout(
#    margin=dict(l=20, r=20, t=20, b=20),

    paper_bgcolor='rgba(1,1,0,0)',
    plot_bgcolor='rgba(1, 1, 0, 0)',
    #xaxis_title="Date",
    yaxis_title="Cumulative Return",
xaxis={'type': 'date', 
       'tick0': time_ind[0], 
        'tickmode': 'linear', 
       'dtick': 86400000.0 *80}

)
fig.update_xaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')

fig.show()
